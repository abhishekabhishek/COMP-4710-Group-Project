# %% [markdown]
# # Notebook for data extraction from last.fm

# %%
# Initialize and autorize the API access
import pylast

# Setup the credentials to access the API
API_KEY = "6d959084dac6e267329098de9eb797f1"
API_SECRET = "a915391ce1cafdb1683f61264792223d"

# User authentication credentials
username = "data_miner"
password_hash = pylast.md5("vicsew-tapZyj-3bagbi")

network = pylast.LastFMNetwork(api_key=API_KEY, api_secret=API_SECRET,
                               username=username, password_hash=password_hash)

# %% [markdown]
# ## 1. Accessing user data

# %%
dir(network)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_delay_call',
#  '_get_cache_backend',
#  '_get_language_domain',
#  '_get_proxy',
#  '_get_url',
#  '_get_ws_auth',
#  'api_key',
#  'api_secret',
#  'cache_backend',
#  'disable_caching',
#  'disable_proxy',
#  'disable_rate_limit',
#  'domain_names',
#  'enable_caching',
#  'enable_proxy',
#  'enable_rate_limit',
#  'get_album',
#  'get_album_by_mbid',
#  'get_artist',
#  'get_artist_by_mbid',
#  'get_authenticated_user',
#  'get_country',
#  'get_geo_top_artists',
#  'get_geo_top_tracks',
#  'get_tag',
#  'get_top_artists',
#  'get_top_tags',
#  'get_top_tracks',
#  'get_track',
#  'get_track_by_mbid',
#  'get_user',
#  'homepage',
#  'is_caching_enabled',
#  'is_proxy_enabled',
#  'is_rate_limited',
#  'last_call_time',
#  'limit_rate',
#  'name',
#  'password_hash',
#  'proxy',
#  'proxy_enabled',
#  'scrobble',
#  'scrobble_many',
#  'search_for_album',
#  'search_for_artist',
#  'search_for_track',
#  'session_key',
#  'update_now_playing',
#  'urls',
#  'username',
#  'ws_server']

# %%
print(dir(network.search_for_track('cher', 'Believe')))

print(network.search_for_track('cher', 'Believe'))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_extract_cdata_from_request', '_get_params', '_get_things', '_last_page_index', '_request', '_retrieve_next_page', '_retrieve_page', '_ws_prefix', 'get_next_page', 'get_total_result_count', 'get_wiki', 'get_wiki_content', 'get_wiki_published_date', 'get_wiki_summary', 'network', 'search_terms', 'ws_prefix']

# %%
network.get_user("10000000000000")
# Out:
# pylast.User('10000000000000', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e'))

# %%
network.get_user("2")
# Out:
# pylast.User('2', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e'))

# %%
# Starting from user 1

user_1 = network.get_user("rj")
dir(user_1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_extract_cdata_from_request',
#  '_get_params',
#  '_get_things',
#  '_request',
#  'get_artist_tracks',
#  'get_country',
#  'get_friends',
#  'get_image',
#  'get_library',
#  'get_loved_tracks',
#  'get_name',
#  'get_now_playing',
#  'get_playcount',
#  'get_recent_tracks',
#  'get_registered',
#  'get_tagged_albums',
#  'get_tagged_artists',
#  'get_tagged_tracks',
#  'get_top_albums',
#  'get_top_artists',
#  'get_top_tags',
#  'get_top_tracks',
#  'get_unixtime_registered',
#  'get_url',
#  'get_weekly_album_charts',
#  'get_weekly_artist_charts',
#  'get_weekly_chart_dates',
#  'get_weekly_charts',
#  'get_weekly_track_charts',
#  'get_wiki',
#  'get_wiki_content',
#  'get_wiki_published_date',
#  'get_wiki_summary',
#  'is_subscriber',
#  'name',
#  'network',
#  'ws_prefix']

# %%
user_1_name = user_1.name
print(user_1_name)
# Out:
# rj

# %%
print(user_1.get_wiki_summary())
# Out:
# None

# %%
user_1_friends = user_1.get_friends()
print(user_1.get_friends(1))
# Out:
# [pylast.User('9', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'bR1w3JSxYxlPDO_GzBcw911a0JSjsqWS', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e'))]

# %%
print(user_1.get_loved_tracks())
# Out:
# [LovedTrack(track=pylast.Track('The Black Seeds', 'Fire', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='04 Apr 2016, 10:53', timestamp='1459767227'), LovedTrack(track=pylast.Track('Gramatik', "Just Jammin'", pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='07 Mar 2016, 13:25', timestamp='1457357120'), LovedTrack(track=pylast.Track('Tahuna Breaks', 'Giddy Up', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='01 Oct 2015, 16:57', timestamp='1443718648'), LovedTrack(track=pylast.Track("Fat Freddy's Drop", 'The Nod', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='07 Sep 2015, 14:23', timestamp='1441635789'), LovedTrack(track=pylast.Track('Gil Scott-Heron', 'Lady Day and John Coltrane', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='07 Sep 2015, 14:08', timestamp='1441634911'), LovedTrack(track=pylast.Track('Aim', "Ain't Got Time To Waste", pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='07 Sep 2015, 13:35', timestamp='1441632958'), LovedTrack(track=pylast.Track('Roman Scott', 'Hold This Down (feat. Dean Curtis)', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='01 Aug 2015, 11:30', timestamp='1438428646'), LovedTrack(track=pylast.Track('Robyn', 'Dancing on My Own', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='31 Jul 2015, 10:34', timestamp='1438338847'), LovedTrack(track=pylast.Track('Steely Dan', 'The Boston Rag', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='11 May 2015, 22:53', timestamp='1431384798'), LovedTrack(track=pylast.Track('Candye Kane', 'You Need Love', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='11 May 2015, 22:41', timestamp='1431384115'), LovedTrack(track=pylast.Track('Gramatik', "Don't You Know", pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='24 Apr 2015, 14:29', timestamp='1429885760'), LovedTrack(track=pylast.Track('Gregory Porter', 'Hey Laura', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='15 Apr 2015, 16:00', timestamp='1429113655'), LovedTrack(track=pylast.Track('Cruzados', 'Mexico', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='07 Mar 2015, 15:54', timestamp='1425743665'), LovedTrack(track=pylast.Track('Tito & Tarantula', 'Pretty Wasted', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f612647 ...

# %%
print(user_1_friends[0].get_loved_tracks())
# Out:
# [LovedTrack(track=pylast.Track('Leonard Cohen', 'Tacoma Trailer', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='17 Dec 2018, 19:52', timestamp='1545076348'), LovedTrack(track=pylast.Track('Blonde Redhead', 'We Should Be Holding Hands', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='17 Dec 2018, 02:55', timestamp='1545015346'), LovedTrack(track=pylast.Track('Pete Seeger', 'Which Side Are You On?', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='16 Dec 2018, 21:00', timestamp='1544994051'), LovedTrack(track=pylast.Track('Pete Seeger', 'Which Side Are You On', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='16 Dec 2018, 20:58', timestamp='1544993907'), LovedTrack(track=pylast.Track('Natalie Merchant', 'Which Side Are You On?', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='16 Dec 2018, 20:50', timestamp='1544993412'), LovedTrack(track=pylast.Track('Nancy Wilson', 'Wild Is The Wind', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='16 Dec 2018, 02:59', timestamp='1544929162'), LovedTrack(track=pylast.Track('Eivør Pálsdóttir', 'Memories of Mother (Farewell to Faye Version) [From "God of War"]', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='16 Dec 2018, 02:26', timestamp='1544927182'), LovedTrack(track=pylast.Track('Underworld', 'Universe of Can When Back', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='15 Dec 2018, 21:16', timestamp='1544908613'), LovedTrack(track=pylast.Track('Whyte Horses', 'Coldest Night Of The Year', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='15 Dec 2018, 20:57', timestamp='1544907464'), LovedTrack(track=pylast.Track('Mercury Rev', 'Big Boss Man', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='15 Dec 2018, 20:19', timestamp='1544905190'), LovedTrack(track=pylast.Track('Ariana Grande', 'Santa Tell Me', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='14 Dec 2018, 21:43', timestamp='1544823835'), LovedTrack(track=pylast.Track('Charlotte Gainsbourg', 'Such A Remarkable Day', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='13 Dec 2018, 04:19', timestamp='1544674743'), LovedTrack(track=pylast.Track('VC Pines', 'Garden of the Year', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), date='12 Dec 2018, 02:39', timestamp='1544582371'), LovedTrac ...

# %%
user_1_tracks = user_1.get_loved_tracks()
print(dir(user_1_tracks[0]))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '_asdict', '_fields', '_make', '_replace', '_source', 'count', 'date', 'index', 'timestamp', 'track']

# %%
print(user_1_tracks[0].count(2))
# Out:
# 0

# %%
print(user_1.get_recent_tracks(1000))
# Out:
# [PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='18 Dec 2018, 06:56', timestamp='1545116178'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='18 Dec 2018, 05:56', timestamp='1545112588'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='18 Dec 2018, 04:56', timestamp='1545108998'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='18 Dec 2018, 03:56', timestamp='1545105407'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='18 Dec 2018, 02:56', timestamp='1545101817'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='18 Dec 2018, 01:57', timestamp='1545098228'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='18 Dec 2018, 00:57', timestamp='1545094638'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='17 Dec 2018, 23:57', timestamp='1545091048'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='17 Dec 2018, 22:57', timestamp='1545087457'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Einschlafhilfe Baby Sleepy', playback_date='17 Dec 2018, 21:57', timestamp='1545083867'), PlayedTrack(track=pylast.Track('Womb Sounds Heartbeat', 'Einschlafhilfe Baby Sleepy - 60 Minuten', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', ' ...

# %%
print(user_1_friends[0].get_recent_tracks(1000))
# Out:
# [PlayedTrack(track=pylast.Track('Daniel Brandt', 'Sailboats III', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Channels', playback_date='18 Dec 2018, 02:19', timestamp='1545099572'), PlayedTrack(track=pylast.Track('Sad Lovers and Giants', 'Paradise', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Mission Creep', playback_date='18 Dec 2018, 02:14', timestamp='1545099286'), PlayedTrack(track=pylast.Track('Jonathan Wilson', 'Loving You', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Loving You (Acoustic Version)', playback_date='18 Dec 2018, 02:09', timestamp='1545098948'), PlayedTrack(track=pylast.Track('Cindy Lee', 'Dry Dive', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Model Express', playback_date='18 Dec 2018, 02:06', timestamp='1545098760'), PlayedTrack(track=pylast.Track('Chad VanGaalen', 'Friendly Aliens', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Friendly Aliens / Monopoly Arp', playback_date='18 Dec 2018, 02:01', timestamp='1545098475'), PlayedTrack(track=pylast.Track('Michelle Blades', 'Kiss Me on the Mouth', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Kiss Me on the Mouth', playback_date='18 Dec 2018, 01:58', timestamp='1545098285'), PlayedTrack(track=pylast.Track('Jah Wobble', 'The Butterfly Effect', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='The Butterfly Effect', playback_date='18 Dec 2018, 01:50', timestamp='1545097856'), PlayedTrack(track=pylast.Track('Field Works', 'Free About Me - Hidden Cities', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='The National Road', playback_date='18 Dec 2018, 01:47', timestamp='1545097654'), PlayedTrack(track=pylast.Track('Building Instrument', 'Lanke', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Mangelen Min', playback_date='18 Dec 2018, 01:43', timestamp='1545097401'), PlayedTrack(track=pylast.Track('St Francis Hotel', 'Collide', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='Collide', playback_date='18 Dec 2018, 01:38', timestamp='1545097118'), PlayedTrack(track=pylast.Track('Blonde Redhead', 'We Should Be Holding Hands', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='We Should Be Holding Hands', playback_date='18 Dec 2018, 01:33', timestamp='1545096835'), PlayedTrack(track=pylast.Track('Leonard Cohen', 'Tacoma Trailer', pylast.LastFMNetwork('6d959084dac6e267329098de9eb797f1', 'a915391ce1cafdb1683f61264792223d', 'yHMSmxw3KJF1m8-T-j7ay-otVWi3kUrm', 'data_miner', '76cf45cb8621ff1fa1e6236b4eb0056e')), album='The Future', playback_date='17  ...

# %%
user_tracks = user_1.get_recent_tracks(100)
dir(user_tracks[0])
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_asdict',
#  '_fields',
#  '_make',
#  '_replace',
#  '_source',
#  'album',
#  'count',
#  'index',
#  'playback_date',
#  'timestamp',
#  'track']

# %%
print(user_tracks[0]._fields)
# Out:
# ('track', 'album', 'playback_date', 'timestamp')

# %%
import requests

# %%
track_info_request = "http://ws.audioscrobbler.com/2.0/?method=track.gettoptags&track=paranoid+android&api_key=6d959084dac6e267329098de9eb797f1&format=json"
r = requests.get(track_info_request)
print(r.text)
# Out:
# {}

# %%
"http://ws.audioscrobbler.com/2.0/?method=user.getrecenttracks&user=rj&api_key=YOUR_API_KEY&format=json"
# Out:
# 'http://ws.audioscrobbler.com/2.0/?method=user.getrecenttracks&user=rj&api_key=YOUR_API_KEY&format=json'

# %% [markdown]
# # More robust data extraction

# %%
# Using the Python module seems to miss some of the important information
# Now using requests module for extracting data
import pylast
import requests

# %%
# Credentials to access the API
API_KEY = "6d959084dac6e267329098de9eb797f1"
API_SECRET = "a915391ce1cafdb1683f61264792223d"

# User authentication credentials
username = "data_miner"
password_hash = pylast.md5("vicsew-tapZyj-3bagbi")

# %%
# Get the first valid user from the API calls
network = pylast.LastFMNetwork(api_key=API_KEY, api_secret=API_SECRET,
                               username=username, password_hash=password_hash)

# %%
# Start from user 1
user_1 = network.get_user("1")

# Extract the friends of user 1
user_1_friends = user_1.get_friends()

# %% [markdown]
# ## Step 1. Extract the previous 10000 tracks listened to by the user

# %%
# Create the user.getrecenttracks request body
tracks_initial_request = 'http://ws.audioscrobbler.com/2.0/?method=user.getrecenttracks&user=' + user_1.name + '&api_key=' + API_KEY + '&format=json' + '&limit=2'
r = requests.get(tracks_initial_request)
print(r.text)
# Out:
# {"recenttracks":{"track":[{"artist":{"#text":"Gin Blossoms","mbid":"1c42b705-d3fc-452e-93ee-d0030bdd70f3"},"name":"Til I Hear It From You","streamable":"0","mbid":"af3111ae-fce8-44b3-9f27-2c940f29cefe","album":{"#text":"Outside Looking In: The Best Of The Gin Blossoms","mbid":"7a4e9b16-29ef-4a04-a69e-425c7ba77901"},"url":"https://www.last.fm/music/Gin+Blossoms/_/Til+I+Hear+It+From+You","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"extralarge"}],"date":{"uts":"1488981297","#text":"08 Mar 2017, 13:54"}},{"artist":{"#text":"Everclear","mbid":"3604c99d-c146-4276-aa0c-9376d333aeb8"},"name":"Santa Monica","streamable":"0","mbid":"4eff8cb5-b9c2-45dc-afe5-52f553ec744b","album":{"#text":"Sparkle And Fade","mbid":"2e1ed15f-fe8e-4239-8930-1389981c34a2"},"url":"https://www.last.fm/music/Everclear/_/Santa+Monica","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/dc6da655ba5b45f2c5dd59c4999f4a29.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/dc6da655ba5b45f2c5dd59c4999f4a29.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/dc6da655ba5b45f2c5dd59c4999f4a29.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/dc6da655ba5b45f2c5dd59c4999f4a29.png","size":"extralarge"}],"date":{"uts":"1488981106","#text":"08 Mar 2017, 13:51"}}],"@attr":{"user":"1","page":"1","perPage":"2","totalPages":"17358","total":"34716"}}}

# %%
# Convert the request output to a dictionary
import json

# Use json.loads to initialize the dictionary
request_output = json.loads(r.text)

# %%
# Type of the return from loads
print(type(request_output))
# Out:
# <class 'dict'>

# %%
# Get the level-1 keys for the dictionary
print(request_output.keys())
# Out:
# dict_keys(['recenttracks'])

# %%
# Get the level-2 keys for the dictionary
print(request_output['recenttracks'].keys())
# Out:
# dict_keys(['track', '@attr'])

# %%
# Get the level-3 keys for the dictionary
print(request_output['recenttracks']['@attr']['total'])
# Out:
# 34716

# %%
print(request_output['recenttracks']['track'])
print(type(request_output['recenttracks']['track']))
# Out:
# [{'mbid': 'af3111ae-fce8-44b3-9f27-2c940f29cefe', 'album': {'mbid': '7a4e9b16-29ef-4a04-a69e-425c7ba77901', '#text': 'Outside Looking In: The Best Of The Gin Blossoms'}, 'streamable': '0', 'artist': {'mbid': '1c42b705-d3fc-452e-93ee-d0030bdd70f3', '#text': 'Gin Blossoms'}, 'name': 'Til I Hear It From You', 'url': 'https://www.last.fm/music/Gin+Blossoms/_/Til+I+Hear+It+From+You', 'date': {'#text': '08 Mar 2017, 13:54', 'uts': '1488981297'}, 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'extralarge'}]}, {'mbid': '4eff8cb5-b9c2-45dc-afe5-52f553ec744b', 'album': {'mbid': '2e1ed15f-fe8e-4239-8930-1389981c34a2', '#text': 'Sparkle And Fade'}, 'streamable': '0', 'artist': {'mbid': '3604c99d-c146-4276-aa0c-9376d333aeb8', '#text': 'Everclear'}, 'name': 'Santa Monica', 'url': 'https://www.last.fm/music/Everclear/_/Santa+Monica', 'date': {'#text': '08 Mar 2017, 13:51', 'uts': '1488981106'}, 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/dc6da655ba5b45f2c5dd59c4999f4a29.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/dc6da655ba5b45f2c5dd59c4999f4a29.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/dc6da655ba5b45f2c5dd59c4999f4a29.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/dc6da655ba5b45f2c5dd59c4999f4a29.png', 'size': 'extralarge'}]}]
# <class 'list'>

# %%
print(len(request_output['recenttracks']['track']))
# Out:
# 2

# %%
print(request_output['recenttracks']['track'][0])
print(type(request_output['recenttracks']['track'][0]))
# Out:
# {'mbid': 'af3111ae-fce8-44b3-9f27-2c940f29cefe', 'album': {'mbid': '7a4e9b16-29ef-4a04-a69e-425c7ba77901', '#text': 'Outside Looking In: The Best Of The Gin Blossoms'}, 'streamable': '0', 'artist': {'mbid': '1c42b705-d3fc-452e-93ee-d0030bdd70f3', '#text': 'Gin Blossoms'}, 'name': 'Til I Hear It From You', 'url': 'https://www.last.fm/music/Gin+Blossoms/_/Til+I+Hear+It+From+You', 'date': {'#text': '08 Mar 2017, 13:54', 'uts': '1488981297'}, 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/b4b0585ed2a94c24cc677aa2d1ee6d0f.png', 'size': 'extralarge'}]}
# <class 'dict'>

# %%
print(request_output['recenttracks']['track'][0]['name'])
# Out:
# Til I Hear It From You

# %%
print(request_output['recenttracks']['track'][0]['artist']['#text'])
# Out:
# Gin Blossoms

# %%
print(request_output['recenttracks']['track'][0]['name'].replace(" ", "+"))
# Out:
# Til+I+Hear+It+From+You

# %% [markdown]
# We can get the total number of tracks listened to by the user using this.

# %% [markdown]
# ## To do : Extract the mbid of the the previous 10000 tracks listened to by the user and all the level 1 friends which have listened to more than 10000 tracks.

# %%
import json
import requests

def get_track_array(user_name):
    
    threshold = 10000
    
    # Determine whether the user actually has listened to more than 10000 tracks
    tracks_initial_request = 'http://ws.audioscrobbler.com/2.0/?method=user.getrecenttracks&user=' + user_name + '&api_key=' + API_KEY + '&format=json' + '&limit=1'
    r = requests.get(tracks_initial_request)
    print('Printing the response for the first request for user : ' + user_name)
    print(r.text)
    
    # Use json.loads to initialize the dictionary
    request_output = json.loads(r.text)
    
    # Get the number of tracks the user has listened to
    num_tracks = int(request_output['recenttracks']['@attr']['total'])
    
    # If the number of tracks is less than threshold
    if num_tracks < threshold :
        print('The user has listened to only ' + str(num_tracks) + ' which is lower than ' + str(threshold))
        return None
    else:
        track_array = []
        page = 1
        
        while( len(track_array) < threshold ):
            
            tracks_request = 'http://ws.audioscrobbler.com/2.0/?method=user.getrecenttracks&user=' + user_name + '&api_key=' + API_KEY + '&format=json' + '&limit=200&page=' + str(page)
            r = requests.get(tracks_request)
            
            # Use json.loads to initialize the dictionary
            request_output = json.loads(r.text)
            
            # Extract the information from the dictionary
            for i in range(len(request_output['recenttracks']['track'])):
                track_name = request_output['recenttracks']['track'][i]['name'].replace(" ", "+")
                artist_name = request_output['recenttracks']['track'][i]['artist']['#text'].replace(" ", "+")
                track_array.append((track_name, artist_name))
            
            page += 1
            
        return track_array

# %%
user_1_track_array = get_track_array(user_1.name)
display(user_1_track_array)
# Out:
# Printing the response for the first request for user : 1
# {"recenttracks":{"track":[{"artist":{"#text":"Gin Blossoms","mbid":"1c42b705-d3fc-452e-93ee-d0030bdd70f3"},"name":"Til I Hear It From You","streamable":"0","mbid":"af3111ae-fce8-44b3-9f27-2c940f29cefe","album":{"#text":"Outside Looking In: The Best Of The Gin Blossoms","mbid":"7a4e9b16-29ef-4a04-a69e-425c7ba77901"},"url":"https://www.last.fm/music/Gin+Blossoms/_/Til+I+Hear+It+From+You","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/b4b0585ed2a94c24cc677aa2d1ee6d0f.png","size":"extralarge"}],"date":{"uts":"1488981297","#text":"08 Mar 2017, 13:54"}}],"@attr":{"user":"1","page":"1","perPage":"1","totalPages":"34716","total":"34716"}}}
# [('Til+I+Hear+It+From+You', 'Gin+Blossoms'),
#  ('Santa+Monica', 'Everclear'),
#  ('Shape+of+You', 'Ed+Sheeran'),
#  ('Purple+Rain', 'Prince'),
#  ("Let's+Go+Crazy", 'Prince'),
#  ('Wish+You+Were+Here', 'Incubus'),
#  ('I+Am+The+Highway', 'Audioslave'),
#  ('The+Man+Who+Sold+the+World', 'Nirvana'),
#  ('Lost+in+Hollywood', 'System+of+a+Down'),
#  ('My+Own+Summer+(Shove+It)', 'Deftones'),
#  ('Would?', 'Alice+in+Chains'),
#  ("It's+Been+Awhile", 'Staind'),
#  ('Numb', 'Linkin+Park'),
#  ('Stay+(with+Alessia+Cara)', 'Zedd'),
#  ("That's+What+I+Like", 'Bruno+Mars'),
#  ('The+Artist+In+The+Ambulance', 'Thrice'),
#  ('Stare+At+The+Sun', 'Thrice'),
#  ("All+That's+Left", 'Thrice'),
#  ('Cold+Cash+Colder+Hearts', 'Thrice'),
#  ('The+Artist+In+The+Ambulance', 'Thrice'),
#  ('Passenger', 'Deftones'),
#  ('My+Own+Summer+(Shove+It)', 'Deftones'),
#  ('Change+(In+the+House+of+Flies)', 'Deftones'),
#  ('When+Doves+Cry', 'Prince'),
#  ('Little+Red+Corvette', 'Prince'),
#  ("Let's+Go+Crazy", 'Prince'),
#  ('Undercover+Martyn', 'Two+Door+Cinema+Club'),
#  ('Something+Good+Can+Work', 'Two+Door+Cinema+Club'),
#  ('What+You+Know', 'Two+Door+Cinema+Club'),
#  ('My+Friends+(feat.+TeamTwin)', 'Mr_hotspot'),
#  ('Juju+On+That+Beat+(TZ+Anthem)', 'Zay+Hilfigerrr'),
#  ('Dab+of+Ranch+-+Recorded+at+Spotify+Studios+NYC', 'Migos'),
#  ('Broccoli', 'D.R.A.M.'),
#  ('679+(Feat.+Remy+Boyz)', 'Fetty+Wap'),
#  ('Bounce+Back', 'Big+Sean'),
#  ('You+Was+Right', 'LIL+UZI+VERT'),
#  ('Caroline', 'Aminé'),
#  ('X+(feat.+Future)', '21+Savage'),
#  ('Bad+and+Boujee+(Feat.+Lil+Uzi+Vert)', 'Migos'),
#  ('Every+Little+Thing', 'Carlene+Carter'),
#  ("You're+Beginning+To+Get+To+Me", 'Clay+Walker'),
#  ('It+Matters+to+Me', 'Faith+Hill'),
#  ('Two+Dozen+Roses', 'Shenandoah'),
#  ('Just+Call+Me+Lonesome', 'Radney+Foster'),
#  ('Some+Girls+Do', 'Sawyer+Brown'),
#  ('I+Try+to+Think+About+Elvis', 'Patty+Loveless'),
#  ('Bobbie+Ann+Mason', 'Rick+Trevino'),
#  ("You've+Got+To+Stand+For+Something", 'Aaron+Tippin'),
#  ('Wink+-+Remastered', 'Neal+McCoy'),
#  ('Strawberry+Wine', 'Deana+Carter'),
#  ("Goin'+Through+The+Big+D", 'Mark+Chesnutt'),
#  ('Forever+And+Ever,+Amen', 'Randy+Travis'),
#  ('Fast+As+you', 'Dwight+Yoakam'),
#  ('Heads+Carolina,+Tails+California', 'Jo+Dee+Messina'),
#  ('Cowboy+Take+Me+Away', 'Dixie+Chicks'),
#  ('God+Blessed+Texas', 'Little+Texas'),
#  ('Sold+(The+Grundy+County+Auction+Incident)', 'John+Michael+Montgomery'),
#  ("Here's+a+Quarter+(Call+Someone+Who+Cares)", 'Travis+Tritt'),
#  ("She+Thinks+My+Tractor's+Sexy", 'Kenny+Chesney'),
#  ('Amarillo+By+Morning', 'George+Strait'),
#  ('Any+Man+of+Mine', 'Shania+Twain'),
#  ("Don't+Let+Our+Love+Start+Slippin'+Away", 'Vince+Gill'),
#  ('Watermelon+Crawl', 'Tracy+Byrd'),
#  ('My+Maria', 'Brooks+&+Dunn'),
#  ("Don't+Let+Our+Love+Start+Slippin'+Away", 'Vince+Gill'),
#  ('Chattahoochee', 'Alan+Jackson'),
#  ("She's+More", 'Andy+Griggs'),
#  ("I'm+in+a+Hurry+(And+Don't+Know+Why)", 'Alabama'),
#  ('Achy+Breaky+Heart', 'Billy+Ray+Cyrus'),
#  ("Thinkin'+Problem", 'David+Ball'),
#  ('Meet+in+the+Middle', 'Diamond+Rio'),
#  ('Swerve+City', 'Deftones'),
#  ('Passenger', 'Deftones'),
#  ('My+Own+Summer+(Shove+It)', 'Deftones'),
#  ('Change+(In+the+House+of+Flies)', 'Deftones'),
#  ("All+That's+Left", 'Thrice'),
#  ('Under+A+Killing+Moon', 'Thrice'),
#  ('Cold+Cash+And+Cold+Hearts', 'Thrice'),
#  ('Silhouette', 'Thrice'),
#  ("All+That's+Left", 'Thrice'),
#  ('Cold+Cash+Colder+Hearts', 'Thrice'),
#  ('The+Artist+In+The+Ambulance', 'Thrice'),
#  ('Digital+Bath', 'Deftones'),
#  ('Back+To+School+-+Mini+Maggit', 'Deftones'),
#  ('Passenger', 'Deftones'),
#  ('My+Own+Summer+(Shove+It)', 'Deftones'),
#  ('Change+(In+the+House+of+Flies)', 'Deftones'),
#  ('Digital+Bath', 'Deftones'),
#  ('Passenger', 'Deftones'),
#  ('My+Own+Summer+(Shove+It)', 'Deftones'),
#  ('Change+(In+the+House+of+Flies)', 'Deftones'),
#  ('Unconsolable', 'X+Ambassadors'),
#  ('Lost+in+Hollywood', 'System+of+a+Down'),
#  ('A+Taste+of+Your+Own+Medicine', 'Chasing+Victory'),
#  ('Down+In+The+DM', 'Yo+Gotti'),
#  ('The+Magdalene+-+Audiotree+Live+Version', 'Foxing'),
#  ('The+Walls+Have+Teeth', 'He+Is+Legend'),
#  ('The+Creature+Walks', 'He+Is+Legend'),
#  ('Eating+a+Book', 'He+Is+Legend'),
#  ('The+Seduction', 'He+Is+Legend'),
#  ('Losing+My+Religion', 'R.E.M.'),
#  ('Outside', 'Tender'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Got+the+Life', 'Korn'),
#  ('Chloe+Dancer/Crown+of+Thorns', 'Mother+Love+Bone'),
#  ('Yellow+Ledbetter', 'Pearl+Jam'),
#  ('Everything+Zen', 'Bush'),
#  ('Outside', 'Tender'),
#  ('Easier', 'Mansionair'),
#  ('Say+Something+Loving', 'The+xx'),
#  ('Conrad', 'SOHN'),
#  ('Say+Something+Loving', 'The+xx'),
#  ('Good+Luck', 'The+Undercover+Dream+Lovers'),
#  ('Conrad', 'SOHN'),
#  ('Lean', 'Blonker'),
#  ('Smoke', 'Mosa+Wild'),
#  ('Outside', 'Tender'),
#  ('Easier', 'Mansionair'),
#  ('Say+Something+Loving', 'The+xx'),
#  ('Good+Luck', 'The+Undercover+Dream+Lovers'),
#  ('Conrad', 'SOHN'),
#  ('iSpy', 'KYLE'),
#  ('Bounce+Back', 'Big+Sean'),
#  ('T-Shirt', 'Migos'),
#  ('Lean', 'Blonker'),
#  ('Walrus', 'D.D+Dumbo'),
#  ('You+Only+Like+Me+with+the+Lights+Out', 'Avid+Dancer'),
#  ('hope', 'tim+legend'),
#  ('Edge+Of+Town', 'Middle+Kids'),
#  ('Into+the+Light', 'J.Viewz'),
#  ('Open+Your+Eyes', 'Starfucker'),
#  ('Fire', 'diskopunk'),
#  ('Compromised', 'Tim+Atlas'),
#  ('Her+Life', 'Two+Feet'),
#  ('Hands+Down', 'The+Greeting+Committee'),
#  ('Smoke', 'Mosa+Wild'),
#  ('Outside', 'Tender'),
#  ('Easier', 'Mansionair'),
#  ('Say+Something+Loving', 'The+xx'),
#  ('Good+Luck', 'The+Undercover+Dream+Lovers'),
#  ('Conrad', 'SOHN'),
#  ('Lean', 'Blonker'),
#  ('Chop+Suey!', 'System+of+a+Down'),
#  ('OTW+(Remix)', 'DJ+Luke+Nasty'),
#  ('Baptized+in+Fire', 'Kid+Cudi'),
#  ('No+Heart', '21+Savage'),
#  ('Swang', 'Rae+Sremmurd'),
#  ('Bad+and+Boujee+(Feat.+Lil+Uzi+Vert)', 'Migos'),
#  ('Silver+and+Cold', 'AFI'),
#  ('Bleed+Black', 'AFI'),
#  ('The+Leaving+Song+Pt.+II', 'AFI'),
#  ('Something+Good', 'alt-J'),
#  ('Dissolve+Me', 'alt-J'),
#  ('Nara', 'alt-J'),
#  ('The+Gospel+of+John+Hurt', 'alt-J'),
#  ('Matilda', 'alt-J'),
#  ('Interlude+1', 'alt-J'),
#  ('Hunger+of+the+Pine', 'alt-J'),
#  ('Under+the+Tide', 'CHVRCHES'),
#  ('Southern+Girl', 'Incubus'),
#  ('Circles', 'Pusha+T'),
#  ('Baptized+in+Fire', 'Kid+Cudi'),
#  ('Unconsolable', 'X+Ambassadors'),
#  ('I+Can+Barely+Breathe', 'Manchester+Orchestra'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Down+In+The+DM', 'Yo+Gotti'),
#  ('Glass+Coughs+-+Audiotree+Live+Version', 'Foxing'),
#  ('Damien+III', 'DMX'),
#  ('Bodyache', 'Purity+Ring'),
#  ('Anna+Molly', 'Incubus'),
#  ('A+Taste+of+Your+Own+Medicine', 'Chasing+Victory'),
#  ('Swang', 'Rae+Sremmurd'),
#  ('iSpy', 'KYLE'),
#  ('Sneakin’', 'Drake'),
#  ('Bounce+Back', 'Big+Sean'),
#  ('Bad+and+Boujee+(Feat.+Lil+Uzi+Vert)', 'Migos'),
#  ('Let+Me+Explain', 'Bryson+Tiller'),
#  ('Wanna+Know+Remix+(feat.+Drake)', 'Dave'),
#  ('Baptized+in+Fire', 'Kid+Cudi'),
#  ("I'm+The+Best+At+Ruining+My+Life", 'From+Autumn+To+Ashes'),
#  ('Alive+Out+Of+Habit', 'From+Autumn+To+Ashes'),
#  ('Lilacs+&+Lolita', 'From+Autumn+To+Ashes'),
#  ('No+Trivia', 'From+Autumn+To+Ashes'),
#  ('Lay+Down', "O'Brother"),
#  ('Enough', 'Private+Island'),
#  ('Inuit', 'Foxing'),
#  ('Lost+in+Hollywood', 'System+of+a+Down'),
#  ('Got+the+Life', 'Korn'),
#  ('Heartsigh', 'Purity+Ring'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('Polly', 'Nirvana'),
#  ('Under+the+Tide', 'CHVRCHES'),
#  ('In+My+Teeth', 'Manchester+Orchestra'),
#  ('A+Crow+Left+of+the+Murder', 'Incubus'),
#  ('The+Neighborhood+Is+Bleeding', 'Manchester+Orchestra'),
#  ('N+2+Gether+Now', 'Limp+Bizkit'),
#  ('Fans', 'Kings+of+Leon'),
#  ('Lay+Down', "O'Brother"),
#  ("Now+That+You're+Home", 'Manchester+Orchestra'),
#  ('The+Medic', 'Foxing'),
#  ('Breathe+Easy', 'Hodera'),
#  ('Baptized+in+Fire', 'Kid+Cudi'),
#  ('Let+Me+Explain', 'Bryson+Tiller'),
#  ('Sidewalks', 'The+Weeknd'),
#  ('Living+Single', 'Big+Sean'),
#  ('Used+to+This', 'Future'),
#  ('Erase+Your+Social', 'LIL+UZI+VERT'),
#  ('Bad+and+Boujee+(Feat.+Lil+Uzi+Vert)', 'Migos'),
#  ('Repetition', 'Purity+Ring'),
#  ('Break+Ya+Neck', 'Busta+Rhymes'),
#  ('Unconsolable', 'X+Ambassadors'),
#  ('Night+Channels', 'Foxing'),
#  ('You+Are+the+Best+Thing', 'Ray+LaMontagne'),
#  ('Eiffel', 'Foxing'),
#  ('About+a+Girl', 'Nirvana'),
#  ('Wyclef+Jean', 'Young+Thug'),
#  ('Chill+Bill', 'Rob+$tone'),
#  ('Baptized+in+Fire', 'Kid+Cudi'),
#  ('They+Like', 'Yo+Gotti'),
#  ('Swang', 'Rae+Sremmurd'),
#  ('Deja+Vu', 'J.+Cole'),
#  ('Bad+and+Boujee+(Feat.+Lil+Uzi+Vert)', 'Migos'),
#  ('Sleigh+Ride', 'Bing+Crosby'),
#  ('Let+It+Snow!+Let+It+Snow!+Let+It+Snow!+-+Remastered', 'Bing+Crosby'),
#  ("I'll+Be+Home+For+Christmas", 'Bing+Crosby'),
#  ('Happy+Holiday', 'Bing+Crosby'),
#  ("It's+Beginning+To+Look+A+Lot+Like+Christmas", 'Bing+Crosby'),
#  ('Maggie+May', 'Rod+Stewart'),
#  ('Faith+-+Remastered', 'George+Michael'),
#  ('Here+We+Come+a-Caroling+/+We+Wish+You+a+Merry+Christmas+-+Remastered',
#   'Perry+Como'),
#  ('Carol+of+the+Bells', 'Mykola+Dmytrovych+Leontovych'),
#  ('The+Christmas+Waltz', 'Peggy+Lee'),
#  ('Run+Rudolph+Run', 'Chuck+Berry'),
#  ('Mele+Kalikimaka+-+Single+Version', 'Bing+Crosby'),
#  ('Mistletoe+and+Holly', 'Frank+Sinatra'),
#  ('The+Little+Drummer+Boy', 'Bing+Crosby'),
#  ('Have+Yourself+a+Merry+Little+Christmas', 'Judy+Garland'),
#  ('Ave+Maria', 'Stevie+Wonder'),
#  ("Children's+Christmas+Song", 'The+Supremes'),
#  ('Dear+Mister+Santa+Claus', 'Hank+Jones'),
#  ('Have+Yourself+a+Merry+Little+Christmas', 'Judy+Garland'),
#  ("It's+Not+Christmas+Without+You", 'Katharine+McPhee'),
#  ("Thank+God+It's+Christmas", 'Queen'),
#  ('Ole+Santa', 'Dinah+Washington'),
#  ("It's+Christmas+Time", 'Kevin+Ross'),
#  ('Sancta+Maria', 'Katherine+Jenkins'),
#  ('Give+Love+On+Christmas+Day', 'The+Temptations'),
#  ('O+Come+All+Ye+Faithful', 'Lionel+Richie'),
#  ('Frosty+The+Snowman', 'The+Jackson+5'),
#  ('O+Holy+Night+-+A+Cappella', '*NSYNC'),
#  ('Merry+Christmas,+Happy+Holidays', '*NSYNC'),
#  ("Rockin'+Around+The+Christmas+Tree", 'Brenda+Lee'),
#  ("It's+Beginning+to+Look+a+Lot+Like+Christmas", 'Michael+Bublé'),
#  ('The+Christmas+Song+(Merry+Christmas+To+You)', 'Nat+King+Cole'),
#  ('Blue+Christmas', 'Elvis+Presley'),
#  ('Last+Christmas', 'Wham!'),
#  ("It's+the+Most+Wonderful+Time+of+the+Year", 'Andy+Williams'),
#  ('Happy+Xmas+(War+Is+Over)', 'Céline+Dion'),
#  ('Santa+Baby', 'Madonna'),
#  ('God+Rest+Ye+Merry+Gentlemen/We+Three+Kings', 'Barenaked+Ladies'),
#  ('A+Holly+Jolly+Christmas+-+Single+Version', 'Burl+Ives'),
#  ("Santa+Claus+Is+Comin'+To+Town+-+Single+Version", 'Bruce+Springsteen'),
#  ('Jingle+Bells', 'Frank+Sinatra'),
#  ('Have+Yourself+a+Merry+Little+Christmas', 'Sam+Smith'),
#  ('All+I+Want+for+Christmas+Is+You', 'Mariah+Carey'),
#  ('Christmas+(Baby+Please+Come+Home)', 'Darlene+Love'),
#  ('Winter+Wonderland+-+2006+-+Remaster', 'Bing+Crosby'),
#  ('Let+It+Snow!+Let+It+Snow!+Let+It+Snow!', 'Ella+Fitzgerald'),
#  ("Do+They+Know+It's+Christmas?", 'Band+Aid'),
#  ('Jingle+Bells', 'Dean+Martin'),
#  ('White+Christmas', 'Bing+Crosby'),
#  ('The+Christmas+Song+(Chestnuts+Roasting+On+An+Open+Fire)',
#   'The+Nat+King+Cole+Trio'),
#  ('Last+Christmas', 'Wham!'),
#  ('Blue+Christmas', 'Elvis+Presley'),
#  ('Winter+Wonderland+-+2006+-+Remaster', 'Bing+Crosby'),
#  ("Rockin'+Around+The+Christmas+Tree", 'Brenda+Lee'),
#  ("Santa+Claus+Is+Comin'+To+Town+-+Single+Version", 'Bruce+Springsteen'),
#  ('Santa+Baby', 'Madonna'),
#  ('A+Holly+Jolly+Christmas+-+Single+Version', 'Burl+Ives'),
#  ("It's+the+Most+Wonderful+Time+of+the+Year", 'Andy+Williams'),
#  ('Jingle+Bells', 'Frank+Sinatra'),
#  ("It's+Beginning+to+Look+a+Lot+Like+Christmas", 'Michael+Bublé'),
#  ('Any+Man+of+Mine', 'Shania+Twain'),
#  ('My+Maria', 'Brooks+&+Dunn'),
#  ('Forever+And+Ever,+Amen', 'Randy+Travis'),
#  ('Caroline', 'Aminé'),
#  ('Baptized+in+Fire', 'Kid+Cudi'),
#  ('Swang', 'Rae+Sremmurd'),
#  ('Bad+and+Boujee+(Feat.+Lil+Uzi+Vert)', 'Migos'),
#  ('Red+Dirt+Road', 'Brooks+&+Dunn'),
#  ("Killin'+Time", 'Clint+Black'),
#  ("I'm+in+a+Hurry+(And+Don't+Know+Why)", 'Alabama'),
#  ('Sold+(The+Grundy+County+Auction+Incident)', 'John+Michael+Montgomery'),
#  ('Meet+in+the+Middle', 'Diamond+Rio'),
#  ('My+Maria', 'Brooks+&+Dunn'),
#  ('I+Told+You+So', 'Randy+Travis'),
#  ('Forever+And+Ever,+Amen', 'Randy+Travis'),
#  ('F.C.P.R.E.M.I.X.', 'The+Fall+of+Troy'),
#  ('In+This+Diary', 'The+Ataris'),
#  ('The+Artist+In+The+Ambulance', 'Thrice'),
#  ('Helena+(So+Long+&+Goodnight)', 'My+Chemical+Romance'),
#  ('One+Armed+Scissor', 'At+the+Drive-In'),
#  ('At+Your+Funeral', 'Saves+the+Day'),
#  ('When+You+Say+Nothing+At+All', 'Alison+Krauss'),
#  ('Six+Feet+Under', 'The+Weeknd'),
#  ('Water', 'Ugly+God'),
#  ('Erase+Your+Social', 'LIL+UZI+VERT'),
#  ('X+(feat.+Future)', '21+Savage'),
#  ('Swang', 'Rae+Sremmurd'),
#  ('Bad+and+Boujee', 'Migos'),
#  ('Everybody+Dies', 'J.+Cole'),
#  ('Blue+Christmas', 'Elvis+Presley'),
#  ('Happy+Xmas+(War+Is+Over)', 'Céline+Dion'),
#  ("It's+the+Most+Wonderful+Time+of+the+Year", 'Andy+Williams'),
#  ('Last+Christmas', 'Wham!'),
#  ("Santa+Claus+Is+Comin'+To+Town+-+Single+Version", 'Bruce+Springsteen'),
#  ('Winter+Wonderland+-+2006+-+Remaster', 'Bing+Crosby'),
#  ("Rockin'+Around+The+Christmas+Tree", 'Brenda+Lee'),
#  ('God+Rest+Ye+Merry+Gentlemen/We+Three+Kings', 'Barenaked+Ladies'),
#  ('All+I+Want+for+Christmas+Is+You', 'Mariah+Carey'),
#  ('Have+Yourself+a+Merry+Little+Christmas', 'Sam+Smith'),
#  ('Fake+Love', 'Drake'),
#  ('Bad+and+Boujee', 'Migos'),
#  ('Bounce+Back', 'Big+Sean'),
#  ('All+I+Want+for+Christmas+Is+You', 'Mariah+Carey'),
#  ('Have+Yourself+a+Merry+Little+Christmas', 'Sam+Smith'),
#  ('La+Grange+-+2005+Remastered+Version', 'ZZ+Top'),
#  ('Rudolph+The+Red-Nosed+Reindeer', 'Barenaked+Ladies'),
#  ('God+Rest+Ye+Merry+Gentlemen/We+Three+Kings', 'Barenaked+Ladies'),
#  ('Do+What+I+Want', 'LIL+UZI+VERT'),
#  ('Smoke+Break+(feat.+Future)', 'Chance+the+Rapper'),
#  ('Broccoli', 'D.R.A.M.'),
#  ('Low+Life', 'Future'),
#  ('OTW', 'DJ+Luke+Nasty'),
#  ('OTW', 'DJ+Luke+Nasty'),
#  ('Rockin’', 'The+Weeknd'),
#  ('Reminder', 'The+Weeknd'),
#  ('Anna+Molly', 'Incubus'),
#  ('Disarm', 'The+Smashing+Pumpkins'),
#  ('Gone+Till+November', 'Wyclef+Jean'),
#  ('Epic', 'Faith+No+More'),
#  ('Killing+In+The+Name+-+Remastered', 'Rage+Against+the+Machine'),
#  ('No+Excuses', 'Alice+in+Chains'),
#  ('Hallelujah', 'Jeff+Buckley'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Black+Beatles', 'Rae+Sremmurd'),
#  ('Gimme+Some+More', 'Busta+Rhymes'),
#  ('Gimme+Some+More', 'Busta+Rhymes'),
#  ('I+Know+What+You+Want', 'Busta+Rhymes'),
#  ('Break+Ya+Neck', 'Busta+Rhymes'),
#  ('Black+Star', 'Radiohead'),
#  ('Epic', 'Faith+No+More'),
#  ('Nothing+Else+Matters', 'Metallica'),
#  ('Song+2+-+2012+Remastered+Version', 'Blur'),
#  ('Sugar+Kane', 'Sonic+Youth'),
#  ('The+Day+I+Tried+to+Live', 'Soundgarden'),
#  ('When+I+Fall+-+Live', 'Barenaked+Ladies'),
#  ('Jane+-+Live', 'Barenaked+Ladies'),
#  ('Break+Your+Heart+-+Live', 'Barenaked+Ladies'),
#  ('Straw+Hat+and+Old+Dirty+Hank+-+Live', 'Barenaked+Ladies'),
#  ('Brian+Wilson+-+Live', 'Barenaked+Ladies'),
#  ('Black+Beatles', 'Rae+Sremmurd'),
#  ('Used+to+This', 'Future'),
#  ('Sneakin’', 'Drake'),
#  ('Satellite', 'Dave+Matthews+Band'),
#  ('What+Would+You+Say', 'Dave+Matthews+Band'),
#  ('Starboy', 'The+Weeknd'),
#  ('Broccoli', 'D.R.A.M.'),
#  ('Starboy', 'The+Weeknd'),
#  ('Broccoli', 'D.R.A.M.'),
#  ('Glass+Coughs+-+Audiotree+Live+Version', 'Foxing'),
#  ('The+Magdalene+-+Audiotree+Live+Version', 'Foxing'),
#  ('Polly', 'Nirvana'),
#  ('About+a+Girl', 'Nirvana'),
#  ('Low', 'Cracker'),
#  ('Far+Behind', 'Candlebox'),
#  ('Karma+Police', 'Radiohead'),
#  ('Megalomaniac', 'Incubus'),
#  ('Unconsolable', 'X+Ambassadors'),
#  ('Push+Pull', 'Purity+Ring'),
#  ('Bodyache', 'Purity+Ring'),
#  ('Ungirthed', 'Purity+Ring'),
#  ('Under+the+Tide', 'CHVRCHES'),
#  ('Leech', 'Incubus'),
#  ('Talk+Shows+on+Mute', 'Incubus'),
#  ('A+Crow+Left+of+the+Murder', 'Incubus'),
#  ('Wish+You+Were+Here', 'Incubus'),
#  ('Anna+Molly', 'Incubus'),
#  ('Clean', 'Incubus'),
#  ('Drive', 'Incubus'),
#  ('Make+Yourself', 'Incubus'),
#  ('Stellar', 'Incubus'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Shake+It+Out', 'Manchester+Orchestra'),
#  ('The+Only+One', 'Manchester+Orchestra'),
#  ('Glass+Coughs+-+Audiotree+Live+Version', 'Foxing'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Ophelia', 'The+Lumineers'),
#  ('Broccoli', 'D.R.A.M.'),
#  ('Unconsolable', 'X+Ambassadors'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Knife+Prty', 'Deftones'),
#  ('Digital+Bath', 'Deftones'),
#  ('Falling+Away+From+Me', 'Korn'),
#  ('Cherub+Rock+-+2011+-+Remaster', 'The+Smashing+Pumpkins'),
#  ('Lost+in+Hollywood', 'System+of+a+Down'),
#  ('Aerials', 'System+of+a+Down'),
#  ('Mr.+Jones', 'Counting+Crows'),
#  ('Got+the+Life', 'Korn'),
#  ('Santa+Monica', 'Everclear'),
#  ('Sex+and+Candy', 'Marcy+Playground'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Seven+Nation+Army', 'Zella+Day'),
#  ('Better+Together', 'Us+The+Duo'),
#  ('Meet+Virginia', 'Train'),
#  ('Song+2+-+2012+Remastered+Version', 'Blur'),
#  ('The+Kill+(Bury+Me)', '30+Seconds+to+Mars'),
#  ('Numb', 'Linkin+Park'),
#  ('Take+a+Look+Around', 'Limp+Bizkit'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Nice+&+Slow', 'Usher'),
#  ('The+Widow', 'As+Cities+Burn'),
#  ('Bloodsucker+Pt.+II', 'As+Cities+Burn'),
#  ('Freak+on+a+Leash', 'Korn'),
#  ('Forever+And+Ever,+Amen', 'Randy+Travis'),
#  ("Cowgirls+Don't+Cry+-+Featuring+Reba+McEntire", 'Brooks+&+Dunn'),
#  ('Neon+Moon', 'Brooks+&+Dunn'),
#  ('Red+Dirt+Road', 'Brooks+&+Dunn'),
#  ('Chattahoochee', 'Alan+Jackson'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Stay+(I+Missed+You)', 'Lisa+Loeb'),
#  ('I+Will+Always+Love+You', 'Whitney+Houston'),
#  ('Talk+Show+Host', 'Radiohead'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Disarm', 'The+Smashing+Pumpkins'),
#  ('Everything+Zen', 'Bush'),
#  ('Shimmer+-+Single+Version', 'Fuel'),
#  ('Fell+on+Black+Days', 'Soundgarden'),
#  ('Santa+Monica', 'Everclear'),
#  ('Piano+Man', 'Billy+Joel'),
#  ('Are+You+Gonna+Go+My+Way', 'Lenny+Kravitz'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('The+Man+Who+Sold+the+World', 'Nirvana'),
#  ('About+a+Girl', 'Nirvana'),
#  ('Low', 'Cracker'),
#  ('Possum+Kingdom', 'Toadies'),
#  ('Disarm', 'The+Smashing+Pumpkins'),
#  ('Cumbersome', 'Seven+Mary+Three'),
#  ('Fell+on+Black+Days', 'Soundgarden'),
#  ('Got+You+(Where+I+Want+You)', 'The+Flys'),
#  ("Friday+I'm+in+Love", 'The+Cure'),
#  ('The+Fallen+Interlude', 'blink-182'),
#  ('Down', 'blink-182'),
#  ('Stockholm+Syndrome', 'blink-182'),
#  ('Obvious', 'blink-182'),
#  ("What's+My+Age+Again?", 'blink-182'),
#  ('Elderly+Woman+Behind+The+Counter+In+A+Small+Town+(Remastered)',
#   'Pearl+Jam'),
#  ('Welcome+to+Paradise', 'Green+Day'),
#  ('Black+Star', 'Radiohead'),
#  ('Dammit', 'blink-182'),
#  ('Live+Forever', 'Oasis'),
#  ('Jane+Says', "Jane's+Addiction"),
#  ('Bound+For+The+Floor', 'Local+H'),
#  ('Everything+Zen', 'Bush'),
#  ('In+the+Meantime', 'Spacehog'),
#  ('Wonderwall', 'Oasis'),
#  ('Good', 'Better+Than+Ezra'),
#  ('You+Really+Got+Me', 'Van+Halen'),
#  ('Take+Me+Home+Tonight', 'Eddie+Money'),
#  ("Jessie's+Girl", 'Rick+Springfield'),
#  ('You+Give+Love+a+Bad+Name', 'Bon+Jovi'),
#  ('We+Are+the+Champions', 'Queen'),
#  ('Sweet+Dreams+(Are+Made+of+This)+-+Remastered+Version', 'Eurythmics'),
#  ('Rock+You+Like+A+Hurricane+-+Live+At+Love+At+First+Sting+Tour', 'Scorpions'),
#  ('I+Love+Rock+And+Roll', 'L.A.+Guns'),
#  ("R.O.C.K.+In+The+U.S.A.+(A+Salute+To+60's+Rock)", 'John+Mellencamp'),
#  ("It's+My+Life+-+1997+Remastered+Version", 'Talk+Talk'),
#  ('Your+Love', 'The+Outfield'),
#  ('What+I+Like+About+You', 'The+Romantics'),
#  ('PRIDE+(IN+THE+NAME+OF+LOVE)', 'U2'),
#  ('Video+Killed+the+Radio+Star', 'The+Buggles'),
#  ('Hungry+Like+the+Wolf', 'Duran+Duran'),
#  ("Don't+You+(Forget+About+Me)", 'Simple+Minds'),
#  ('Material+Girl', 'Madonna'),
#  ('Eye+of+the+Tiger', 'Survivor'),
#  ("Free+Fallin'", 'Tom+Petty+and+The+Heartbreakers'),
#  ('Rebel+Yell+-+1999+-+Remaster', 'Billy+Idol'),
#  ('Shout', 'Tears+for+Fears'),
#  ('Beat+It+-+Single+Version', 'Michael+Jackson'),
#  ('Whip+It', 'Devo'),
#  ('867-5309+/+Jenny', 'Tommy+Tutone'),
#  ("Livin'+on+a+Prayer", 'Bon+Jovi'),
#  ('Island+in+the+Sun', 'Weezer'),
#  ("Summer+of+'69", 'Bryan+Adams'),
#  ('Too+Good', 'Drake'),
#  ('Let+Me+Love+You', 'DJ+Snake'),
#  ('Heathens', 'Twenty+One+Pilots'),
#  ('Piano+Man', 'Billy+Joel'),
#  ('What+I+Got', 'Sublime'),
#  ('Drive', 'Incubus'),
#  ('Sometimes', 'DMX'),
#  ('Tha+Crossroads', 'Bone+Thugs-N-Harmony'),
#  ('Stranger+Things', 'Kyle+Dixon'),
#  ('Meet+Virginia', 'Train'),
#  ('Ride', 'Twenty+One+Pilots'),
#  ('Controlla', 'Drake'),
#  ('Too+Good', 'Drake'),
#  ("Don't+Let+Me+Down", 'The+Chainsmokers'),
#  ('Needed+Me', 'Rihanna'),
#  ('Broccoli', 'D.R.A.M.'),
#  ('Too+Good', 'Drake'),
#  ('Let+Me+Love+You', 'DJ+Snake'),
#  ('One+Dance', 'Drake'),
#  ('Heathens', 'Twenty+One+Pilots'),
#  ('Needed+Me', 'Rihanna'),
#  ('Too+Good', 'Drake'),
#  ('One+Dance', 'Drake'),
#  ('Cradle+(Better+Nature)', 'Silversun+Pickups'),
#  ('A.D.I.D.A.S.', 'Korn'),
#  ('Falling+Away+From+Me', 'Korn'),
#  ('Freak+on+a+Leash', 'Korn'),
#  ('Ophelia', 'The+Lumineers'),
#  ('Shimmer+-+Single+Version', 'Fuel'),
#  ('Sex+and+Candy', 'Marcy+Playground'),
#  ('Santa+Monica', 'Everclear'),
#  ('Even+Flow', 'Pearl+Jam'),
#  ('Breathe+Easy', 'Hodera'),
#  ('Unconsolable', 'X+Ambassadors'),
#  ('Breathe+Easy', 'Hodera'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('No+Cigar', 'Millencolin'),
#  ('Seabass', 'Private+Island'),
#  ('Sleeper+1972', 'Manchester+Orchestra'),
#  ('I+Can+Barely+Breathe', 'Manchester+Orchestra'),
#  ('Where+Have+You+Been?', 'Manchester+Orchestra'),
#  ("Now+That+You're+Home", 'Manchester+Orchestra'),
#  ('Tiny+Raindrop', 'Balance+and+Composure'),
#  ('Reflection', 'Balance+and+Composure'),
#  ('Tiny+Raindrop', 'Balance+and+Composure'),
#  ('Colly+Strings', 'Manchester+Orchestra'),
#  ("Don't+Let+Them+See+You+Cry", 'Manchester+Orchestra'),
#  ('Alice+And+Interiors', 'Manchester+Orchestra'),
#  ('Golden+Ticket', 'Manchester+Orchestra'),
#  ('Sleeper+1972', 'Manchester+Orchestra'),
#  ('I+Can+Barely+Breathe', 'Manchester+Orchestra'),
#  ('Where+Have+You+Been?', 'Manchester+Orchestra'),
#  ('I+Can+Feel+Your+Pain', 'Manchester+Orchestra'),
#  ('The+Neighborhood+Is+Bleeding', 'Manchester+Orchestra'),
#  ('One+Dance', 'Drake'),
#  ('Ride', 'Twenty+One+Pilots'),
#  ('Controlla', 'Drake'),
#  ('This+Is+What+You+Came+For', 'Calvin+Harris'),
#  ('Needed+Me', 'Rihanna'),
#  ('Too+Good', 'Drake'),
#  ('One+Dance', 'Drake'),
#  ('One+Dance', 'Drake'),
#  ('Too+Good', 'Drake'),
#  ('Coda', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Lost+in+Hollywood', 'System+of+a+Down'),
#  ("This+Cocaine+Makes+Me+Feel+Like+I'm+On+This+Song", 'System+of+a+Down'),
#  ('Aerials', 'System+of+a+Down'),
#  ('When+We+Were+on+Fire', 'James+Bay'),
#  ('Move+Together', 'James+Bay'),
#  ('Dancing+Through+Sunday', 'AFI'),
#  ('Silver+and+Cold', 'AFI'),
#  ('Bleed+Black', 'AFI'),
#  ('The+Leaving+Song+Pt.+II', 'AFI'),
#  ('Lost+in+Hollywood', 'System+of+a+Down'),
#  ('Lost+in+Hollywood', 'System+of+a+Down'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Three+On+A+Match+-+Audiotree+Live+Version', 'Foxing'),
#  ('Glass+Coughs+-+Audiotree+Live+Version', 'Foxing'),
#  ('The+Magdalene+-+Audiotree+Live+Version', 'Foxing'),
#  ('Jimmy,+He+Whispers', 'Manchester+Orchestra'),
#  ('The+River', 'Manchester+Orchestra'),
#  ('Everything+To+Nothing', 'Manchester+Orchestra'),
#  ('Tony+The+Tiger', 'Manchester+Orchestra'),
#  ('My+Friend+Marcus', 'Manchester+Orchestra'),
#  ('I+Can+Feel+a+Hot+One', 'Manchester+Orchestra'),
#  ('100+Dollars', 'Manchester+Orchestra'),
#  ('In+My+Teeth', 'Manchester+Orchestra'),
#  ('Pride', 'Manchester+Orchestra'),
#  ("I've+Got+Friends", 'Manchester+Orchestra'),
#  ('Night+Channels+-+Audiotree+Live+Version', 'Foxing'),
#  ('Three+On+A+Match+-+Audiotree+Live+Version', 'Foxing'),
#  ('Glass+Coughs+-+Audiotree+Live+Version', 'Foxing'),
#  ('Redwoods+-+Audiotree+Live+Version', 'Foxing'),
#  ('The+Magdalene+-+Audiotree+Live+Version', 'Foxing'),
#  ('7+Years', 'Lukas+Graham'),
#  ('One+Dance', 'Drake'),
#  ('One+Dance', 'Drake'),
#  ('In+My+Teeth', 'Manchester+Orchestra'),
#  ('Alice+And+Interiors', 'Manchester+Orchestra'),
#  ('I+Can+Barely+Breathe', 'Manchester+Orchestra'),
#  ('Three+on+a+Match', 'Foxing'),
#  ('The+Magdalene', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Inuit', 'Foxing'),
#  ('Redwoods', 'Foxing'),
#  ('Break+Stuff', 'Limp+Bizkit'),
#  ('Heartsigh', 'Purity+Ring'),
#  ('I+Took+A+Pill+In+Ibiza+-+SeeB+Remix', 'Mike+Posner'),
#  ("Don't+Mind", 'Kent+Jones'),
#  ('One+Dance', 'Drake'),
#  ('Recover', 'CHVRCHES'),
#  ('Under+the+Tide', 'CHVRCHES'),
#  ('Too+Good', 'Drake'),
#  ("Don't+Let+Me+Down", 'The+Chainsmokers'),
#  ('Panda', 'Desiigner'),
#  ('Can\'t+Stop+the+Feeling!+(Original+Song+from+DreamWorks+Animation+"TROLLS")',
#   'Justin+Timberlake'),
#  ('This+Is+What+You+Came+For', 'Calvin+Harris'),
#  ('Outro', 'Limp+Bizkit'),
#  ('Pop+Style', 'Drake'),
#  ("Don't+Mind", 'Kent+Jones'),
#  ("Don't+Let+Me+Down", 'The+Chainsmokers'),
#  ('Stressed+Out', 'Twenty+One+Pilots'),
#  ('Cheap+Thrills', 'Sia'),
#  ('I+Took+A+Pill+In+Ibiza+-+SeeB+Remix', 'Mike+Posner'),
#  ("Don't+Mind", 'Kent+Jones'),
#  ("Don't+Let+Me+Down", 'The+Chainsmokers'),
#  ('Panda', 'Desiigner'),
#  ('Warning', 'Cymbals+Eat+Guitars'),
#  ('Sunburn', 'Diamond+Youth'),
#  ('Chambers', 'Cymbals+Eat+Guitars'),
#  ('Turn+Your+Love', 'Half+Moon+Run'),
#  ('Undone', 'Paerish'),
#  ('My+Head+Hurts', 'Wavves'),
#  ('Sunburn', 'Diamond+Youth'),
#  ('Claustrophobe', 'Laura+Stevenson'),
#  ('Chambers', 'Cymbals+Eat+Guitars'),
#  ('Turn+Your+Love', 'Half+Moon+Run'),
#  ('Undone', 'Paerish'),
#  ('Claustrophobe', 'Laura+Stevenson'),
#  ('Turn+Your+Love', 'Half+Moon+Run'),
#  ('Undone', 'Paerish'),
#  ('My+Head+Hurts', 'Wavves'),
#  ('Sunburn', 'Diamond+Youth'),
#  ('Claustrophobe', 'Laura+Stevenson'),
#  ('Chambers', 'Cymbals+Eat+Guitars'),
#  ('Turn+Your+Love', 'Half+Moon+Run'),
#  ('Undone', 'Paerish'),
#  ('Rory', 'Foxing'),
#  ('Three+on+a+Match', 'Foxing'),
#  ('The+Magdalene', 'Foxing'),
#  ('Bit+By+Dead+Bee+pt+II', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('Inuit', 'Foxing'),
#  ("I've+Got+Friends", 'Manchester+Orchestra'),
#  ("Tears+Don't+Fall", 'Bullet+for+My+Valentine'),
#  ('The+Crimson', 'Atreyu'),
#  ("Ex's+And+Oh's", 'Atreyu'),
#  ('Already+Dead', 'Silverstein'),
#  ('Bullet+Theory', 'Funeral+for+a+Friend'),
#  ('Last+Train+Home', 'Lostprophets'),
#  ('Savior', 'Rise+Against'),
#  ('No+Cigar', 'Millencolin'),
#  ('Message+in+a+Bottle', 'The+Police'),
#  ('How+Soon+Is+Now?', 'The+Smiths'),
#  ('Lord+Pretty+Flacko+Jodye+2+(LPFJ2)', 'A$AP+Rocky'),
#  ('First+Class', 'Rainbow+Kitten+Surprise'),
#  ('Above+the+Clouds+of+Pompeii', "Bear's+Den"),
#  ('Architect', 'Manchester+Orchestra,+Frightened+Rabbit'),
#  ('Weave', 'Foxing'),
#  ('Dearly+Departed', 'Shakey+Graves'),
#  ('Greek+Tragedy', 'The+Wombats'),
#  ('Love,+Love,+Love+(Love,+Love)', 'As+Tall+As+Lions'),
#  ('The+Night', 'Honne'),
#  ('Queen', 'Perfume+Genius'),
#  ('Push+Pull', 'Purity+Ring'),
#  ('Bros', 'Wolf+Alice'),
#  ('The+Magdalene', 'Foxing'),
#  ('Believe', 'Mumford+&+Sons'),
#  ('Oh+My+God', 'Hollow+Wood'),
#  ('In+My+Teeth', 'Manchester+Orchestra'),
#  ("I've+Got+Friends", 'Manchester+Orchestra'),
#  ('Shake+It+Out', 'Manchester+Orchestra'),
#  ('The+Only+One', 'Manchester+Orchestra'),
#  ('Everything+To+Nothing', 'Manchester+Orchestra'),
#  ('Tony+The+Tiger', 'Manchester+Orchestra'),
#  ('My+Friend+Marcus', 'Manchester+Orchestra'),
#  ('In+My+Teeth', 'Manchester+Orchestra'),
#  ('Pride', 'Manchester+Orchestra'),
#  ("I've+Got+Friends", 'Manchester+Orchestra'),
#  ('Shake+It+Out', 'Manchester+Orchestra'),
#  ('The+Only+One', 'Manchester+Orchestra'),
#  ('The+Neighborhood+Is+Bleeding', 'Manchester+Orchestra'),
#  ('I+Can+Feel+Your+Pain', 'Manchester+Orchestra'),
#  ('The+Neighborhood+Is+Bleeding', 'Manchester+Orchestra'),
#  ("Now+That+You're+Home", 'Manchester+Orchestra'),
#  ('Wolves+At+Night', 'Manchester+Orchestra'),
#  ('Of+Want+And+Misery:The+Nothing+That+Kills', 'As+Cities+Burn'),
#  ('The+Widow', 'As+Cities+Burn'),
#  ('Terrible!+How+Terrible+For+The+Great+City!', 'As+Cities+Burn'),
#  ('Bloodsucker+Pt.+II', 'As+Cities+Burn'),
#  ('If+You+Ever+Want+to+Be+in+Love', 'James+Bay'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Hold+Back+the+River', 'James+Bay'),
#  ('Craving', 'James+Bay'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('Move+Together', 'James+Bay'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Bit+By+Dead+Bee+pt+II', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('The+Magdalene', 'Foxing'),
#  ('Bit+By+Dead+Bee+pt+II', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Bit+By+Dead+Bee+pt+II', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Collide', 'James+Bay'),
#  ('Scars', 'James+Bay'),
#  ('Move+Together', 'James+Bay'),
#  ('When+We+Were+on+Fire', 'James+Bay'),
#  ('Best+Fake+Smile', 'James+Bay'),
#  ('If+You+Ever+Want+to+Be+in+Love', 'James+Bay'),
#  ('Hold+Back+the+River', 'James+Bay'),
#  ('Craving', 'James+Bay'),
#  ('Collide', 'James+Bay'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Night+Channels', 'Foxing'),
#  ('The+Magdalene', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('Inuit', 'Foxing'),
#  ('Move+Together', 'James+Bay'),
#  ('Get+Out+While+You+Can', 'James+Bay'),
#  ('Collide', 'James+Bay'),
#  ('Scars', 'James+Bay'),
#  ('Move+Together', 'James+Bay'),
#  ('Best+Fake+Smile', 'James+Bay'),
#  ('If+You+Ever+Want+to+Be+in+Love', 'James+Bay'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Hold+Back+the+River', 'James+Bay'),
#  ('Craving', 'James+Bay'),
#  ('Closer', 'Kings+of+Leon'),
#  ('Fans', 'Kings+of+Leon'),
#  ('7+Years', 'Lukas+Graham'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Stealing+Cars', 'James+Bay'),
#  ('Need+the+Sun+to+Break', 'James+Bay'),
#  ('When+We+Were+On+Fire+-+The+Dark+Of+The+Morning+Version', 'James+Bay'),
#  ('Hold+Back+the+River', 'James+Bay'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Love+Yourself', 'Justin+Bieber'),
#  ('I+Took+A+Pill+In+Ibiza+-+SeeB+Remix', 'Mike+Posner'),
#  ('7+Years', 'Lukas+Graham'),
#  ('Friendly+Advice', 'Bad+Books'),
#  ('42', 'Bad+Books'),
#  ('Petite+Mort', 'Bad+Books'),
#  ('The+After+Party', 'Bad+Books'),
#  ('It+Never+Stops', 'Bad+Books'),
#  ('Pyotr', 'Bad+Books'),
#  ('Forest+Whitaker', 'Bad+Books'),
#  ('Pyotr', 'Bad+Books'),
#  ('Forest+Whitaker', 'Bad+Books'),
#  ('The+After+Party', 'Bad+Books'),
#  ('Mama+Said', 'Lukas+Graham'),
#  ('7+Years', 'Lukas+Graham'),
#  ('Change+The+World', 'Eric+Clapton'),
#  ('Cocaine', 'Eric+Clapton'),
#  ('Hold+Back+the+River', 'James+Bay'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Roses', 'The+Chainsmokers'),
#  ('7+Years', 'Lukas+Graham'),
#  ('Hide+Away', 'Daya'),
#  ('Jumpman', 'Drake'),
#  ('7+Years', 'Lukas+Graham'),
#  ('Stressed+Out', 'Twenty+One+Pilots'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Sunshine+On+My+Back', 'The+National'),
#  ('Adversity', 'Beach+Fossils'),
#  ('Hearing+Blue', 'Little+Tybee'),
#  ('1999', 'Active+Child'),
#  ('Wildman', 'Sun+Drug'),
#  ('Scud+Running', 'Prawn'),
#  ('Run+Wild,+Young+Beauty', 'Hotel+Books'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Let+It+Go', 'James+Bay'),
#  ('Old+Love', 'Eric+Clapton'),
#  ('Malted+Milk', 'Eric+Clapton'),
#  ('San+Francisco+Bay+Blues', 'Eric+Clapton'),
#  ('Alberta', 'Eric+Clapton'),
#  ("Walkin'+Blues", 'Eric+Clapton'),
#  ('Running+on+Faith', 'Eric+Clapton'),
#  ('Layla', 'Eric+Clapton'),
#  ("Nobody+Knows+You+When+You're+Down+and+Out", 'Eric+Clapton'),
#  ('Lonely+Stranger', 'Eric+Clapton'),
#  ('Tears+in+Heaven', 'Eric+Clapton'),
#  ('Hey+Hey', 'Eric+Clapton'),
#  ('Before+You+Accuse+Me', 'Eric+Clapton'),
#  ('Signe', 'Eric+Clapton'),
#  ('Tether', 'CHVRCHES'),
#  ('Down+In+The+DM', 'Yo+Gotti'),
#  ('King+Sh*t', 'Yo+Gotti'),
#  ('Crawl', 'Kings+of+Leon'),
#  ('Closer', 'Kings+of+Leon'),
#  ('King+Of+The+Rodeo', 'Kings+of+Leon'),
#  ('Fans', 'Kings+of+Leon'),
#  ('On+Call', 'Kings+of+Leon'),
#  ('Revelry', 'Kings+of+Leon'),
#  ('Manhattan', 'Kings+of+Leon'),
#  ('Closer', 'Kings+of+Leon'),
#  ('Matilda', 'alt-J'),
#  ('Something+Good', 'alt-J'),
#  ('Dissolve+Me', 'alt-J'),
#  ('Fitzpleasure', 'alt-J'),
#  ('Hunger+of+the+Pine', 'alt-J'),
#  ('Enough', 'Private+Island'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('Dissolve', 'Private+Island'),
#  ('Drugs', 'Private+Island'),
#  ('Tessellate', 'alt-J'),
#  ('Interlude+1', 'alt-J'),
#  ('Bloodflood,+Part+II', 'alt-J'),
#  ('Bloodflood', 'alt-J'),
#  ('Matilda', 'alt-J'),
#  ('Something+Good', 'alt-J'),
#  ('Dissolve+Me', 'alt-J'),
#  ('Down+In+The+DM', 'Yo+Gotti'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Weave', 'Foxing'),
#  ('Redwoods', 'Foxing'),
#  ('Winding+Cloth', 'Foxing'),
#  ('Indica', 'Foxing'),
#  ('Laundered', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('The+Magdalene', 'Foxing'),
#  ('Weave', 'Foxing'),
#  ('The+Magdalene', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Lay+Down', "O'Brother"),
#  ('The+Medic', 'Foxing'),
#  ('Down+In+The+DM', 'Yo+Gotti'),
#  ('I+Can+Barely+Breathe', 'Manchester+Orchestra'),
#  ('Where+Have+You+Been?', 'Manchester+Orchestra'),
#  ('The+Neighborhood+Is+Bleeding', 'Manchester+Orchestra'),
#  ("Now+That+You're+Home", 'Manchester+Orchestra'),
#  ('Wolves+At+Night', 'Manchester+Orchestra'),
#  ('Down+In+The+DM', 'Yo+Gotti'),
#  ('Down+In+The+DM', 'Yo+Gotti'),
#  ('Hey+Maria', 'Audio+Karate'),
#  ('Architect', 'Manchester+Orchestra,+Frightened+Rabbit'),
#  ('Begin+Again', 'Purity+Ring'),
#  ('Stranger+Than+Earth', 'Purity+Ring'),
#  ('Repetition', 'Purity+Ring'),
#  ('Push+Pull', 'Purity+Ring'),
#  ('Bodyache', 'Purity+Ring'),
#  ('Heartsigh', 'Purity+Ring'),
#  ('Coda', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('Coda', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Dissolve', 'Private+Island'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('Televators', 'The+Mars+Volta'),
#  ('Eriatarka', 'The+Mars+Volta'),
#  ('Son+et+Lumiere', 'The+Mars+Volta'),
#  ('War+All+The+Time', 'Thursday'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Redwoods', 'Foxing'),
#  ('Laundered', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('Enough', 'Private+Island'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('Dissolve', 'Private+Island'),
#  ('Bear+Hands', 'Private+Island'),
#  ('Polly', 'Nirvana'),
#  ('Polly', 'Nirvana'),
#  ('About+a+Girl', 'Nirvana'),
#  ('Polly', 'Nirvana'),
#  ('Notebook', 'Majical+Cloudz'),
#  ('Bugs+Don’t+Buzz', 'Majical+Cloudz'),
#  ('Turns+Turns+Turns', 'Majical+Cloudz'),
#  ('Childhood’s+End', 'Majical+Cloudz'),
#  ('This+Is+Magic', 'Majical+Cloudz'),
#  ('The+Medic', 'Foxing'),
#  ('Bit+By+Dead+Bee+pt+I', 'Foxing'),
#  ('Inuit', 'Foxing'),
#  ('Bloodhound', 'Foxing'),
#  ('Coda', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('The+Medic', 'Foxing'),
#  ('Heaven', 'Majical+Cloudz'),
#  ('Wait+&+See', 'Majical+Cloudz'),
#  ('Downtown', 'Majical+Cloudz'),
#  ('No+Rain+-+2002+-+Remastered', 'Blind+Melon'),
#  ('Freak+on+a+Leash', 'Korn'),
#  ('Fell+on+Black+Days', 'Soundgarden'),
#  ('Shimmer+-+Single+Version', 'Fuel'),
#  ('Tomorrow+-+Remastered', 'Silverchair'),
#  ('Alive', 'Pearl+Jam'),
#  ('Everlong', 'Foo+Fighters'),
#  ('Treehouse', 'Dios+Mio'),
#  ('Arrow', 'StoneFox'),
#  ('Laundered', 'Foxing'),
#  ('Night+Channels', 'Foxing'),
#  ('The+Magdalene', 'Foxing'),
#  ('Weave', 'Foxing'),
#  ('No+Rain+-+2002+-+Remastered', 'Blind+Melon'),
#  ('The+Beautiful+People', 'Marilyn+Manson'),
#  ('Disarm', 'The+Smashing+Pumpkins'),
#  ('Cumbersome', 'Seven+Mary+Three'),
#  ('Everlong', 'Foo+Fighters'),
#  ('Bleed+To+Love+Her+-+Live', 'Fleetwood+Mac'),
#  ('Rhiannon+-+Live', 'Fleetwood+Mac'),
#  ('Dreams+-+Live', 'Fleetwood+Mac'),
#  ('the+chain+-+Live', 'Fleetwood+Mac'),
#  ('Down+in+a+Hole', 'Alice+in+Chains'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('New+Level', 'A$AP+Ferg'),
#  ('Jersey', 'Future'),
#  ('Sowing+Season+(Yeah)', 'Brand+New'),
#  ('Degausser', 'Brand+New'),
#  ("You+Won't+Know", 'Brand+New'),
#  ('Gum', 'Moose+Blood'),
#  ('Bros', 'Wolf+Alice'),
#  ('Dissolve', 'Private+Island'),
#  ('Keep+Yourself+Warm', 'Frightened+Rabbit'),
#  ('Architect', 'Manchester+Orchestra,+Frightened+Rabbit'),
#  ('Night+Channels', 'Foxing'),
#  ('Eiffel', 'Foxing'),
#  ('Glass+Coughs', 'Foxing'),
#  ('Holy', 'Frightened+Rabbit'),
#  ('The+Modern+Leper', 'Frightened+Rabbit'),
#  ('Keep+Yourself+Warm', 'Frightened+Rabbit'),
#  ('Swim+Until+You+Can’t+See+Land', 'Frightened+Rabbit'),
#  ('The+Woodpile', 'Frightened+Rabbit'),
#  ('The+Night', 'Honne'),
#  ('Architect', 'Manchester+Orchestra,+Frightened+Rabbit'),
#  ('Bros', 'Wolf+Alice'),
#  ('Repetition', 'Purity+Ring'),
#  ('Push+Pull', 'Purity+Ring'),
#  ('Bodyache', 'Purity+Ring'),
#  ('Heartsigh', 'Purity+Ring'),
#  ('Push+Pull', 'Purity+Ring'),
#  ('Bodyache', 'Purity+Ring'),
#  ('Heartsigh', 'Purity+Ring'),
#  ('Bros', 'Wolf+Alice'),
#  ('Architect', 'Manchester+Orchestra,+Frightened+Rabbit'),
#  ('Bear+Hands', 'Private+Island'),
#  ('Come+As+You+Are', 'Yuna'),
#  ('Santa+Monica+Dream', 'Angus+Stone'),
#  ('Stay+Loose', 'Broncho'),
#  ('Leave+a+Trace', 'CHVRCHES'),
#  ('how+do+you+tell+a+girl+you+really+like+her+eyes?+(FULL+BAND+DEMO)',
#   'Cyberbully+Mom+Club'),
#  ('Bros', 'Wolf+Alice'),
#  ('We+Sink', 'CHVRCHES'),
#  ('Never+Ending+Circles', 'CHVRCHES'),
#  ('Enough', 'Private+Island'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('Dissolve', 'Private+Island'),
#  ('Mishka', 'Private+Island'),
#  ('Dissolve', 'Private+Island'),
#  ('Mishka', 'Private+Island'),
#  ('Enough', 'Private+Island'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('On+My+Mind', 'Ellie+Goulding'),
#  ("I'll+Show+You", 'Justin+Bieber'),
#  ('Roses', 'The+Chainsmokers'),
#  ('Same+Old+Love', 'Selena+Gomez'),
#  ('Here', 'Alessia+Cara'),
#  ('Hotline+Bling', 'Drake'),
#  ('Same+Old+Love', 'Selena+Gomez'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ("Don't+Call+Me", 'Private+Island'),
#  ('Mishka', 'Private+Island'),
#  ...]

# %%
user_1_friends = user_1.get_friends()
user_1_friends_track_array = []

# Extract the track array for all the friends and append to the main array
for friend in user_1_friends:
    user_1_friends_track_array.append(get_track_array(friend.name))
# Out:
# Printing the response for the first request for user : 9
# {"recenttracks":{"track":[{"artist":{"#text":"Ariel Pink's Haunted Graffiti","mbid":"4ac6c2fd-daad-4c31-b266-017c79d2e9a9"},"name":"Baby","streamable":"0","mbid":"ffec11c2-80bf-4e92-a63d-07bd76f5568e","album":{"#text":"Mature Themes","mbid":"12860ae7-5d2a-4df7-99df-875efcdd885e"},"url":"https://www.last.fm/music/Ariel+Pink%27s+Haunted+Graffiti/_/Baby","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/8c53b5f498634d8db9401635bf2ecbb4.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/8c53b5f498634d8db9401635bf2ecbb4.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/8c53b5f498634d8db9401635bf2ecbb4.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/8c53b5f498634d8db9401635bf2ecbb4.png","size":"extralarge"}],"date":{"uts":"1545157295","#text":"18 Dec 2018, 18:21"}}],"@attr":{"user":"9","page":"1","perPage":"1","totalPages":"232323","total":"232323"}}}
# Printing the response for the first request for user : kcmauceri
# {"recenttracks":{"track":[{"artist":{"#text":"From First to Last","mbid":"7f36c2ba-a338-402f-861f-390229bfae04"},"name":"Note To Self","streamable":"0","mbid":"bd48d799-29ef-49bd-bff1-b212b54f7c9d","album":{"#text":"Dear Diary","mbid":""},"url":"https://www.last.fm/music/From+First+to+Last/_/Note+To+Self","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/b38f1a82dd9d4cb0af521fa235485edb.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/b38f1a82dd9d4cb0af521fa235485edb.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/b38f1a82dd9d4cb0af521fa235485edb.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/b38f1a82dd9d4cb0af521fa235485edb.png","size":"extralarge"}],"date":{"uts":"1420591997","#text":"07 Jan 2015, 00:53"}}],"@attr":{"user":"kcmauceri","page":"1","perPage":"1","totalPages":"5551","total":"5551"}}}
# The user has listened to only 5551 which is lower than 10000
# Printing the response for the first request for user : as1230
# {"recenttracks":{"track":[],"@attr":{"user":"as1230","page":"1","perPage":"1","totalPages":"0","total":"0"}}}
# The user has listened to only 0 which is lower than 10000
# Printing the response for the first request for user : nathanon2
# {"recenttracks":{"track":[{"artist":{"#text":"Darude","mbid":"9ffad8aa-b671-4a9a-a527-a95bdaaa0ec4"},"name":"Sandstorm","streamable":"0","mbid":"5cb4ee75-a2c9-4650-b141-730b6ca03aad","album":{"#text":"","mbid":""},"url":"https://www.last.fm/music/Darude/_/Sandstorm","image":[{"#text":"","size":"small"},{"#text":"","size":"medium"},{"#text":"","size":"large"},{"#text":"","size":"extralarge"}],"date":{"uts":"1429491055","#text":"20 Apr 2015, 00:50"}}],"@attr":{"user":"nathanon2","page":"1","perPage":"1","totalPages":"80300","total":"80300"}}}
# Printing the response for the first request for user : Last_RichFM
# {"recenttracks":{"track":[{"artist":{"#text":"Matt Simons","mbid":"e14eb176-68e9-434e-9a55-da2718c454d8"},"name":"With You","streamable":"0","mbid":"65c16197-9cda-438b-b0b6-4582c52cbbde","album":{"#text":"Pieces","mbid":"5cddcd67-1265-4776-bf3d-e5428474260d"},"url":"https://www.last.fm/music/Matt+Simons/_/With+You","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/03695ba41a4643d193fcafc6e4098642.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/03695ba41a4643d193fcafc6e4098642.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/03695ba41a4643d193fcafc6e4098642.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/03695ba41a4643d193fcafc6e4098642.png","size":"extralarge"}],"date":{"uts":"1359322224","#text":"27 Jan 2013, 21:30"}}],"@attr":{"user":"Last_RichFM","page":"1","perPage":"1","totalPages":"60823","total":"60823"}}}
# Printing the response for the first request for user : zoelfix
# {"recenttracks":{"track":[{"artist":{"#text":"Paramore","mbid":"728ea90d-279b-4201-a8c4-597830883150"},"name":"When It Rains","streamable":"0","mbid":"e72ffc21-1ca3-442d-bd00-4477b82fae29","album":{"#text":"RIOT!","mbid":"c79bc474-e712-49ff-8185-89b52384ba45"},"url":"https://www.last.fm/music/Paramore/_/When+It+Rains","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/b7a4b3000d0c431fbce299986ac51c48.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/b7a4b3000d0c431fbce299986ac51c48.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/b7a4b3000d0c431fbce299986ac51c48.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/b7a4b3000d0c431fbce299986ac51c48.png","size":"extralarge"}],"date":{"uts":"1317212942","#text":"28 Sep 2011, 12:29"}}],"@attr":{"user":"zoelfix","page":"1","perPage":"1","totalPages":"498","total":"498"}}}
# The user has listened to only 498 which is lower than 10000
# Printing the response for the first request for user : jennaskeletor
# {"recenttracks":{"track":[{"artist":{"#text":"Tycho","mbid":"cbef45a9-7acb-4325-94c9-70081ac8d1b8"},"name":"Melanine","streamable":"0","mbid":"bf1c34a9-d9b4-4a76-943c-0a55b6579e52","album":{"#text":"","mbid":""},"url":"https://www.last.fm/music/Tycho/_/Melanine","image":[{"#text":"","size":"small"},{"#text":"","size":"medium"},{"#text":"","size":"large"},{"#text":"","size":"extralarge"}],"date":{"uts":"1417994466","#text":"07 Dec 2014, 23:21"}}],"@attr":{"user":"jennaskeletor","page":"1","perPage":"1","totalPages":"20857","total":"20857"}}}
# Printing the response for the first request for user : GiovannaPrado
# {"recenttracks":{"track":[{"artist":{"#text":"Motorama","mbid":"c7bee23e-f9bb-4dee-b1e3-5d49f81cde11"},"name":"Sometimes","streamable":"0","mbid":"e7be4283-749b-47a7-8a86-1a337b4c91ad","album":{"#text":"Calendar","mbid":"d875ef5f-09f1-4c56-9771-e64769e8c70b"},"url":"https://www.last.fm/music/Motorama/_/Sometimes","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/1d00b3127ac54b8f90460e52519d6c0e.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/1d00b3127ac54b8f90460e52519d6c0e.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/1d00b3127ac54b8f90460e52519d6c0e.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/1d00b3127ac54b8f90460e52519d6c0e.png","size":"extralarge"}],"date":{"uts":"1400705338","#text":"21 May 2014, 20:48"}}],"@attr":{"user":"GiovannaPrado","page":"1","perPage":"1","totalPages":"7200","total":"7200"}}}
# The user has listened to only 7200 which is lower than 10000
# Printing the response for the first request for user : aziam
# {"recenttracks":{"track":[{"artist":{"#text":"Desert Sessions","mbid":"7a2e6b55-f149-4e74-be6a-30a1b1a387bb"},"name":"Powdered Wig Machine","streamable":"0","mbid":"16e5e25c-bb9c-49c7-a707-62c52df6f111","album":{"#text":"","mbid":""},"url":"https://www.last.fm/music/Desert+Sessions/_/Powdered+Wig+Machine","image":[{"#text":"","size":"small"},{"#text":"","size":"medium"},{"#text":"","size":"large"},{"#text":"","size":"extralarge"}],"date":{"uts":"1302293553","#text":"08 Apr 2011, 20:12"}}],"@attr":{"user":"aziam","page":"1","perPage":"1","totalPages":"3917","total":"3917"}}}
# The user has listened to only 3917 which is lower than 10000
# Printing the response for the first request for user : bittersinner
# {"recenttracks":{"track":[],"@attr":{"user":"bittersinner","page":"1","perPage":"1","totalPages":"0","total":"0"}}}
# The user has listened to only 0 which is lower than 10000
# Printing the response for the first request for user : WeAreSparkly
# {"recenttracks":{"track":[{"artist":{"#text":"Green Day","mbid":"084308bd-1654-436f-ba03-df6697104e19"},"name":"21st Century Breakdown","streamable":"0","mbid":"e806d1ac-96c3-4207-87ea-1c414ad9e5f9","album":{"#text":"21st Century Breakdown","mbid":"b266af07-7453-4e02-aa7a-c9d00369ec5d"},"url":"https://www.last.fm/music/Green+Day/_/21st+Century+Breakdown","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/c5f9c64c345ea23b986e8e39d75d0656.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/c5f9c64c345ea23b986e8e39d75d0656.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/c5f9c64c345ea23b986e8e39d75d0656.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/c5f9c64c345ea23b986e8e39d75d0656.png","size":"extralarge"}],"date":{"uts":"1352991564","#text":"15 Nov 2012, 14:59"}}],"@attr":{"user":"WeAreSparkly","page":"1","perPage":"1","totalPages":"136","total":"136"}}}
# The user has listened to only 136 which is lower than 10000
# Printing the response for the first request for user : plasticvenus88
# {"recenttracks":{"track":[{"artist":{"#text":"Grimes","mbid":"7e5a2a59-6d9f-4a17-b7c2-e1eedb7bd222"},"name":"California","streamable":"0","mbid":"","album":{"#text":"Art Angels","mbid":""},"url":"https://www.last.fm/music/Grimes/_/California","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/61eba443a5860ef71aef011bc77bbc63.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/61eba443a5860ef71aef011bc77bbc63.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/61eba443a5860ef71aef011bc77bbc63.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/61eba443a5860ef71aef011bc77bbc63.png","size":"extralarge"}],"date":{"uts":"1449098032","#text":"02 Dec 2015, 23:13"}}],"@attr":{"user":"plasticvenus88","page":"1","perPage":"1","totalPages":"66699","total":"66699"}}}
# Printing the response for the first request for user : openboy
# {"recenttracks":{"track":[{"artist":{"#text":"萧敬腾","mbid":""},"name":"阿飞的小蝴蝶","streamable":"0","mbid":"","album":{"#text":"王妃","mbid":""},"url":"https://www.last.fm/music/%E8%90%A7%E6%95%AC%E8%85%BE/_/%E9%98%BF%E9%A3%9E%E7%9A%84%E5%B0%8F%E8%9D%B4%E8%9D%B6","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/32c21b60e0b340deb01288c0661219b5.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/32c21b60e0b340deb01288c0661219b5.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/32c21b60e0b340deb01288c0661219b5.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/32c21b60e0b340deb01288c0661219b5.png","size":"extralarge"}],"date":{"uts":"1460299761","#text":"10 Apr 2016, 14:49"}}],"@attr":{"user":"openboy","page":"1","perPage":"1","totalPages":"25613","total":"25613"}}}
# Printing the response for the first request for user : rjgriggs
# {"recenttracks":{"track":[{"artist":{"#text":"Horse Feathers","mbid":"20efa62f-4f98-4bdd-abcc-3e6cfb90d271"},"name":"Dustbowl","streamable":"0","mbid":"6f760d2b-4e40-4eed-95cc-7a5cb9640db9","album":{"#text":"Words Are Dead","mbid":"a81849f3-aab1-429c-8c06-ed78f9d68181"},"url":"https://www.last.fm/music/Horse+Feathers/_/Dustbowl","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/94010b71af5146e1b915df1474f1651d.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/94010b71af5146e1b915df1474f1651d.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/94010b71af5146e1b915df1474f1651d.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/94010b71af5146e1b915df1474f1651d.png","size":"extralarge"}],"date":{"uts":"1272884497","#text":"03 May 2010, 11:01"}}],"@attr":{"user":"rjgriggs","page":"1","perPage":"1","totalPages":"2","total":"2"}}}
# The user has listened to only 2 which is lower than 10000
# Printing the response for the first request for user : wonderfullyrach
# {"recenttracks":{"track":[{"artist":{"#text":"Big Spider's Back","mbid":"f299187a-3b39-4b34-90eb-9dcee39f5b71"},"name":"Don't Make Me Laugh","streamable":"0","mbid":"","album":{"#text":"","mbid":""},"url":"https://www.last.fm/music/Big+Spider%27s+Back/_/Don%27t+Make+Me+Laugh","image":[{"#text":"","size":"small"},{"#text":"","size":"medium"},{"#text":"","size":"large"},{"#text":"","size":"extralarge"}],"date":{"uts":"1428876606","#text":"12 Apr 2015, 22:10"}}],"@attr":{"user":"wonderfullyrach","page":"1","perPage":"1","totalPages":"15909","total":"15909"}}}
# Printing the response for the first request for user : Emfulz
# {"recenttracks":{"track":[{"artist":{"#text":"Rise Against","mbid":"606bf117-494f-4864-891f-09d63ff6aa4b"},"name":"Give It All","streamable":"0","mbid":"9daec74e-bbdf-46a9-965d-91da0a472305","album":{"#text":"Siren Song of the Counter Culture","mbid":"b447d048-2d72-4fb7-9b6e-1bb4e3f245e7"},"url":"https://www.last.fm/music/Rise+Against/_/Give+It+All","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/42f276f33c3244a5c48627af92733300.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/42f276f33c3244a5c48627af92733300.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/42f276f33c3244a5c48627af92733300.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/42f276f33c3244a5c48627af92733300.png","size":"extralarge"}],"date":{"uts":"1376327534","#text":"12 Aug 2013, 17:12"}}],"@attr":{"user":"Emfulz","page":"1","perPage":"1","totalPages":"79273","total":"79273"}}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-be2aa2a493b3> in <module>()
#       4 # Extract the track array for all the friends and append to the main array
#       5 for friend in user_1_friends:
# ----> 6     user_1_friends_track_array.append(get_track_array(friend.name))
#
# <ipython-input-37-683ed9e6a4ab> in get_track_array(user_name)
#      29
#      30             tracks_request = 'http://ws.audioscrobbler.com/2.0/?method=user.getrecenttracks&user=' + user_name + '&api_key=' + API_KEY + '&format=json' + '&limit=200&page=' + str(page)
# ---> 31             r = requests.get(tracks_request)
#      32
#      33             # Use json.loads to initialize the dictionary
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     355             conn.request_chunked(method, url, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#     359         # Reset the timeout for the recv() on the socket
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\http\client.py in request(self, method, url, body, headers)
#    1105     def request(self, method, url, body=None, headers={}):
#    1106         """Send a complete request to the server."""
# -> 1107         self._send_request(method, url, body, headers)
#    1108
#    1109     def _set_content_length(self, body, method):
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1150             # default charset of iso-8859-1.
#    1151             body = _encode(body, 'body')
# -> 1152         self.endheaders(body)
#    1153
#    1154     def getresponse(self):
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\http\client.py in endheaders(self, message_body)
#    1101         else:
#    1102             raise CannotSendHeader()
# -> 1103         self._send_output(message_body)
#    1104
#    1105     def request(self, method, url, body=None, headers={}):
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\http\client.py in _send_output(self, message_body)
#     932         del self._buffer[:]
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#     936             self.send(message_body)
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\http\client.py in send(self, data)
#     875         if self.sock is None:
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#     879                 raise NotConnected()
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\urllib3\connection.py in connect(self)
#     164
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#     168
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:

# %% [markdown]
# ## Now that the track arrays has been extracted, map the tracks to Genres using toptag

# %%
sample_track_request = 'http://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist=Big+Sean&track=Bounce+Back&api_key=6d959084dac6e267329098de9eb797f1&format=json'
sample_r = requests.get(sample_track_request)

# Use json.loads to initialize the dictionary
sample_request_output = json.loads(sample_r.text)

# %%
display(sample_request_output)

# %%
display(sample_request_output.keys())

# %%
display(sample_request_output['toptags'].keys())

# %%
display(type(sample_request_output['toptags']['tag']))

# %%
display(sample_request_output['toptags']['tag'][0]['name'])

# %%
from json import JSONDecodeError

def map_to_genre(track_array, threshold=50):
    
    mapped_array = []
    unique_tags = []
    track_index = 0
    
    # Map all the tracks in the given array to their respective arrays
    for track_info in track_array:
        
        add = True
        
        track = track_info[0].replace("#", "")
        artist = track_info[1].replace("#", "")
        
        track = track.replace("&", "and")
        artist = artist.replace("&", "and")
        
        if "Featuring" in track:
            track = track[:track.find("Featuring")]
            
        
        try:
            toptag_request = 'http://ws.audioscrobbler.com/2.0/?method=track.gettoptags&track=' + track + '&artist=' + artist + '&api_key=' + API_KEY + '&format=json'
            r = requests.get(toptag_request)
        
            # Use json.loads to initialize the dictionary
            request_output = json.loads(r.text)
            
        except JSONDecodeError:
            print('Unsuccessful request : ' + toptag_request)
            add = False

        if( add ):
            
            try:

                # Extract the current track genre from the dict
                if( len(request_output['toptags']['tag']) > 0 ):

                    if(len(unique_tags) < threshold):

                        tag = request_output['toptags']['tag'][0]['name']

                        mapped_array.append(tag)

                        if tag not in unique_tags: 
                            unique_tags.append(tag)

                    else:

                        if( len(request_output['toptags']['tag']) == 1 ):
                            tag = request_output['toptags']['tag'][0]['name']
                            mapped_array.append(tag)
                            if tag not in unique_tags: 
                                unique_tags.append(tag)

                        else:

                            index = 0
                            tag_added = False

                            while(index < len(request_output['toptags']['tag']) and not tag_added):

                                tag = request_output['toptags']['tag'][index]['name']

                                if tag in unique_tags:
                                    mapped_array.append(tag)
                                    tag_added = True

                                index += 1

                            if not tag_added:
                                
                                tag = request_output['toptags']['tag'][0]['name']
                                mapped_array.append(tag)
                                
                                if tag not in unique_tags:
                                    unique_tags.append(tag)
                                
                                tag_added = True

            except KeyError:
                print("Key not found for track = " + track + " and artist = " + artist)
                print(request_output)
        
        track_index += 1

    return mapped_array, unique_tags

# %%
print(len(user_1_track_array))
print(user_1_track_array)
# Out:
# 10000
# [('Til+I+Hear+It+From+You', 'Gin+Blossoms'), ('Santa+Monica', 'Everclear'), ('Shape+of+You', 'Ed+Sheeran'), ('Purple+Rain', 'Prince'), ("Let's+Go+Crazy", 'Prince'), ('Wish+You+Were+Here', 'Incubus'), ('I+Am+The+Highway', 'Audioslave'), ('The+Man+Who+Sold+the+World', 'Nirvana'), ('Lost+in+Hollywood', 'System+of+a+Down'), ('My+Own+Summer+(Shove+It)', 'Deftones'), ('Would?', 'Alice+in+Chains'), ("It's+Been+Awhile", 'Staind'), ('Numb', 'Linkin+Park'), ('Stay+(with+Alessia+Cara)', 'Zedd'), ("That's+What+I+Like", 'Bruno+Mars'), ('The+Artist+In+The+Ambulance', 'Thrice'), ('Stare+At+The+Sun', 'Thrice'), ("All+That's+Left", 'Thrice'), ('Cold+Cash+Colder+Hearts', 'Thrice'), ('The+Artist+In+The+Ambulance', 'Thrice'), ('Passenger', 'Deftones'), ('My+Own+Summer+(Shove+It)', 'Deftones'), ('Change+(In+the+House+of+Flies)', 'Deftones'), ('When+Doves+Cry', 'Prince'), ('Little+Red+Corvette', 'Prince'), ("Let's+Go+Crazy", 'Prince'), ('Undercover+Martyn', 'Two+Door+Cinema+Club'), ('Something+Good+Can+Work', 'Two+Door+Cinema+Club'), ('What+You+Know', 'Two+Door+Cinema+Club'), ('My+Friends+(feat.+TeamTwin)', 'Mr_hotspot'), ('Juju+On+That+Beat+(TZ+Anthem)', 'Zay+Hilfigerrr'), ('Dab+of+Ranch+-+Recorded+at+Spotify+Studios+NYC', 'Migos'), ('Broccoli', 'D.R.A.M.'), ('679+(Feat.+Remy+Boyz)', 'Fetty+Wap'), ('Bounce+Back', 'Big+Sean'), ('You+Was+Right', 'LIL+UZI+VERT'), ('Caroline', 'Aminé'), ('X+(feat.+Future)', '21+Savage'), ('Bad+and+Boujee+(Feat.+Lil+Uzi+Vert)', 'Migos'), ('Every+Little+Thing', 'Carlene+Carter'), ("You're+Beginning+To+Get+To+Me", 'Clay+Walker'), ('It+Matters+to+Me', 'Faith+Hill'), ('Two+Dozen+Roses', 'Shenandoah'), ('Just+Call+Me+Lonesome', 'Radney+Foster'), ('Some+Girls+Do', 'Sawyer+Brown'), ('I+Try+to+Think+About+Elvis', 'Patty+Loveless'), ('Bobbie+Ann+Mason', 'Rick+Trevino'), ("You've+Got+To+Stand+For+Something", 'Aaron+Tippin'), ('Wink+-+Remastered', 'Neal+McCoy'), ('Strawberry+Wine', 'Deana+Carter'), ("Goin'+Through+The+Big+D", 'Mark+Chesnutt'), ('Forever+And+Ever,+Amen', 'Randy+Travis'), ('Fast+As+you', 'Dwight+Yoakam'), ('Heads+Carolina,+Tails+California', 'Jo+Dee+Messina'), ('Cowboy+Take+Me+Away', 'Dixie+Chicks'), ('God+Blessed+Texas', 'Little+Texas'), ('Sold+(The+Grundy+County+Auction+Incident)', 'John+Michael+Montgomery'), ("Here's+a+Quarter+(Call+Someone+Who+Cares)", 'Travis+Tritt'), ("She+Thinks+My+Tractor's+Sexy", 'Kenny+Chesney'), ('Amarillo+By+Morning', 'George+Strait'), ('Any+Man+of+Mine', 'Shania+Twain'), ("Don't+Let+Our+Love+Start+Slippin'+Away", 'Vince+Gill'), ('Watermelon+Crawl', 'Tracy+Byrd'), ('My+Maria', 'Brooks+&+Dunn'), ("Don't+Let+Our+Love+Start+Slippin'+Away", 'Vince+Gill'), ('Chattahoochee', 'Alan+Jackson'), ("She's+More", 'Andy+Griggs'), ("I'm+in+a+Hurry+(And+Don't+Know+Why)", 'Alabama'), ('Achy+Breaky+Heart', 'Billy+Ray+Cyrus'), ("Thinkin'+Problem", 'David+Ball'), ('Meet+in+the+Middle', 'Diamond+Rio'), ('Swerve+City', 'Deftones'), ('Passenger', 'Deftones'), ('My+Own+Summer+(Shove+It)', 'Deftones'), ('Change+(In+the+House+of+Flies)', 'Deftones'), ("All+That's+Left", 'Thrice'), ('Under+A+Killing+Moon', 'Thrice'), ('Cold+Cash+And+Cold+Hearts', 'Thrice'), ('Silhouette', 'Thrice'), ("All+That's+Left", 'Thrice'), ('Cold+Cash+Colder+Hearts', 'Thrice'), ('The+Artist+In+The+Ambulance', 'Thrice'), ('Digital+Bath', 'Deftones'), ('Back+To+School+-+Mini+Maggit', 'Deftones'), ('Passenger', 'Deftones'), ('My+Own+Summer+(Shove+It)', 'Deftones'), ('Change+(In+the+House+of+Flies)', 'Deftones'), ('Digital+Bath', 'Deftones'), ('Passenger', 'Deftones'), ('My+Own+Summer+(Shove+It)', 'Deftones'), ('Change+(In+the+House+of+Flies)', 'Deftones'), ('Unconsolable', 'X+Ambassadors'), ('Lost+in+Hollywood', 'System+of+a+Down'), ('A+Taste+of+Your+Own+Medicine', 'Chasing+Victory'), ('Down+In+The+DM', 'Yo+Gotti'), ('The+Magdalene+-+Audiotree+Live+Version', 'Foxing'), ('The+Walls+Have+Teeth', 'He+Is+Legend'), ('The+Creature+Walks', 'He+Is+Legend'), ('Eating+a+Book', 'He+Is+Legend'), ('The+Seduction', 'He+Is+Legend'), ('Losing+My+Religion', ' ...

# %%
genre_sequence, unique_genres = map_to_genre(user_1_track_array)
# Out:
# Key not found for track = Cowgirls+Don't+Cry+-+ and artist = Brooks+and+Dunn
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Believe and artist = Mumford+and+Sons
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Ottoman+(from+"Nick+and+Norah's+Infinite+Playlist") and artist = Movie+Favorites
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Downtown+(feat.+Eric+Nally,+Melle+Mel,+Kool+Moe+Dee+and+Grandmaster+Caz) and artist = Macklemore+and+Ryan+Lewis
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Downtown+(feat.+Eric+Nally,+Melle+Mel,+Kool+Moe+Dee+and+Grandmaster+Caz) and artist = Macklemore+and+Ryan+Lewis
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Downtown+(feat.+Eric+Nally,+Melle+Mel,+Kool+Moe+Dee+and+Grandmaster+Caz) and artist = Macklemore+and+Ryan+Lewis
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Downtown+(feat.+Eric+Nally,+Melle+Mel,+Kool+Moe+Dee+and+Grandmaster+Caz) and artist = Macklemore+and+Ryan+Lewis
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Believe and artist = Mumford+and+Sons
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Believe and artist = Mumford+and+Sons
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Believe and artist = Mumford+and+Sons
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 41+-+Live+At+Wrigley+Field and artist = Dave+Matthews+Band
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 41+-+Live+At+Wrigley+Field and artist = Dave+Matthews+Band
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 41+-+Live+At+Wrigley+Field and artist = Dave+Matthews+Band
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 41+-+Live+At+Wrigley+Field and artist = Dave+Matthews+Band
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 41+-+Live+At+Wrigley+Field and artist = Dave+Matthews+Band
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 41+-+Live+At+Wrigley+Field and artist = Dave+Matthews+Band
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Lycanthrope and artist = +44
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Make+You+Smile and artist = +44
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Make+You+Smile and artist = +44
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Lycanthrope and artist = +44
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Make+You+Smile and artist = +44
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 155 and artist = +44
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = All+I+Ask+Of+You+( and artist = Warren+G
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = All+I+Ask+Of+You+( and artist = Warren+G
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = *uck+You+and+Your+Filthy+AandR+Dept. and artist = Weerd+Science
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = All+I+Ask+Of+You+( and artist = Warren+G
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = I+Hear+Voices+( and artist = Puff+Daddy
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 001++PRINCE+-+WHEN+DOVES+CRY and artist = Prince
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 001++PRINCE+-+WHEN+DOVES+CRY and artist = Prince
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 001++PRINCE+-+WHEN+DOVES+CRY and artist = Prince
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = 001++PRINCE+-+WHEN+DOVES+CRY and artist = Prince
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Punkass+/+Are+You+Out+Of+Your+F+in'+Mind?! and artist = Dane+Cook
# {'error': 6, 'links': [], 'message': 'Track not found'}
# Key not found for track = Stunting+Like+My+Dady and artist = Birdman+and+Lil'+Wayne
# {'error': 6, 'links': [], 'message': 'Track not found'}

# %%
display(genre_sequence)
# Out:
# ['90s',
#  '90s',
#  'pop',
#  '80s',
#  '80s',
#  'alternative rock',
#  'rock',
#  'Grunge',
#  'alternative metal',
#  'Nu Metal',
#  'Grunge',
#  'rock',
#  'rock',
#  'alessia cara',
#  'funk',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'alternative',
#  'Nu Metal',
#  'metal',
#  '80s',
#  '80s',
#  '80s',
#  'indie',
#  'indie',
#  'indie',
#  'Hip-Hop',
#  'hiphop',
#  'rap',
#  'Hip-Hop',
#  'trap',
#  'Hip-Hop',
#  'rap',
#  'meme rap',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'alternative metal',
#  'alternative',
#  'Nu Metal',
#  'metal',
#  'rock',
#  'post-hardcore',
#  '2003',
#  'post-hardcore',
#  'rock',
#  'rock',
#  'alternative',
#  'alternative metal',
#  'alternative',
#  'Nu Metal',
#  'metal',
#  'alternative',
#  'alternative',
#  'Nu Metal',
#  'metal',
#  'like2009-2014',
#  'alternative metal',
#  'screamo',
#  'Hip-Hop',
#  'hardcore',
#  'metalcore',
#  'post-hardcore',
#  'post-hardcore',
#  'rock',
#  'folk',
#  'Nu Metal',
#  'Grunge',
#  'Grunge',
#  'Grunge',
#  'chillstep',
#  'electronic',
#  'electropop',
#  'electronic',
#  'sxsw 2017',
#  'electropop',
#  'chillstep',
#  'electronic',
#  'sxsw 2017',
#  'electropop',
#  'lil yachty',
#  'Hip-Hop',
#  'trap',
#  'Fave Indie Pop',
#  'conan',
#  'Philkas',
#  'sadboi',
#  'chillstep',
#  'electronic',
#  'sxsw 2017',
#  'electropop',
#  'alternative metal',
#  'Hip-Hop',
#  'rap',
#  'Hip-Hop',
#  'meme rap',
#  'punk',
#  'punk',
#  'punk',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'synthpop',
#  'rock',
#  'rap',
#  'Hip-Hop',
#  'like2009-2014',
#  'indie',
#  'folk',
#  'Hip-Hop',
#  'Hip-Hop',
#  '2015',
#  'rock',
#  'screamo',
#  'Hip-Hop',
#  'lil yachty',
#  'Hip-Hop',
#  'Hip-Hop',
#  'meme rap',
#  'american',
#  'Hip-Hop',
#  'Hip-Hop',
#  'metalcore',
#  'hardcore',
#  'hardcore',
#  'emo',
#  'post-rock',
#  'emo',
#  'alternative metal',
#  'Nu Metal',
#  'synthpop',
#  'Grunge',
#  'synthpop',
#  'indie',
#  'alternative',
#  'indie',
#  'Hip-Hop',
#  'rock',
#  'post-rock',
#  'indie',
#  'emo',
#  'indie',
#  'Hip-Hop',
#  'american',
#  'Hip-Hop',
#  'Hip-Hop',
#  'Hip-Hop',
#  'Hip-Hop',
#  'meme rap',
#  'electronica',
#  'Hip-Hop',
#  'like2009-2014',
#  'soul',
#  'Grunge',
#  'Hip-Hop',
#  'Hip-Hop',
#  'Hip-Hop',
#  'Hip-Hop',
#  'meme rap',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'classic rock',
#  'catchy af',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'jazz',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'easy listening',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'country',
#  'country',
#  'country',
#  'Hip-Hop',
#  'Hip-Hop',
#  'Hip-Hop',
#  'meme rap',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'country',
#  'post-hardcore',
#  'punk rock',
#  'rock',
#  'post-hardcore',
#  'emo',
#  'country',
#  'hip hop',
#  'hip hop',
#  'Hip-Hop',
#  'rap',
#  'Hip-Hop',
#  'hip hop',
#  'Hip-Hop',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'christmas',
#  'trap',
#  'hip hop',
#  'Hip-Hop',
#  'christmas',
#  'christmas',
#  'classic rock',
#  'christmas',
#  'christmas',
#  'Hip-Hop',
#  'future',
#  'hiphop',
#  'rap',
#  'pop',
#  'rap',
#  'rock',
#  'alternative rock',
#  'Hip-Hop',
#  'rock',
#  'alternative',
#  'Grunge',
#  'rock',
#  'folk',
#  'rap',
#  'Hip-Hop',
#  'Hip-Hop',
#  'rap',
#  'Hip-Hop',
#  'rock',
#  'rock',
#  'metal',
#  'alternative rock',
#  'alternative',
#  'Grunge',
#  'rap',
#  'Hip-Hop',
#  'Hip-Hop',
#  'rock',
#  'rock',
#  'electronic',
#  'hiphop',
#  'electronic',
#  'hiphop',
#  'Grunge',
#  'Grunge',
#  'alternative',
#  'Grunge',
#  'alternative',
#  'rock',
#  'like2009-2014',
#  'indie',
#  '2015',
#  'electronic',
#  'synthpop',
#  'alternative rock',
#  'rock',
#  'alternative',
#  'alternative rock',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'folk',
#  'indie',
#  'indie',
#  'folk',
#  'folk',
#  'alternative',
#  'hiphop',
#  'like2009-2014',
#  'emo',
#  'metal',
#  'alternative',
#  'Nu Metal',
#  'Grunge',
#  'alternative metal',
#  'metal',
#  'rock',
#  'Nu Metal',
#  '90s',
#  '90s',
#  'folk',
#  'indie',
#  'rock',
#  'alternative rock',
#  'rock',
#  'rock',
#  'rock',
#  'folk',
#  'soul',
#  'post-hardcore',
#  'post-hardcore',
#  'Nu Metal',
#  'country',
#  'country',
#  'country',
#  'country',
#  'folk',
#  '90s',
#  'pop',
#  'alternative',
#  'folk',
#  'alternative rock',
#  'Grunge',
#  'alternative rock',
#  'Grunge',
#  '90s',
#  'classic rock',
#  'rock',
#  'folk',
#  'Grunge',
#  'Grunge',
#  'alternative',
#  '90s',
#  'alternative rock',
#  '90s',
#  'Grunge',
#  '90s',
#  '80s',
#  'punk rock',
#  'punk rock',
#  'punk rock',
#  'punk rock',
#  'punk rock',
#  'folk',
#  'punk rock',
#  'rock',
#  'punk rock',
#  'rock',
#  'alternative rock',
#  'rock',
#  'Grunge',
#  '90s',
#  'rock',
#  '90s',
#  'classic rock',
#  '80s',
#  '80s',
#  'rock',
#  'classic rock',
#  '80s',
#  'hard rock',
#  'classic rock',
#  'synthpop',
#  '80s',
#  '80s',
#  'rock',
#  '80s',
#  '80s',
#  '80s',
#  'pop',
#  '80s',
#  'classic rock',
#  '80s',
#  '80s',
#  'pop',
#  '80s',
#  '80s',
#  'rock',
#  'rock',
#  'rock',
#  'pop',
#  'electronic',
#  'alternative',
#  'classic rock',
#  '90s',
#  'rock',
#  'hip hop',
#  'Hip-Hop',
#  'ost',
#  'rock',
#  'rock',
#  'Hip-Hop',
#  'pop',
#  'electronic',
#  'Hip-Hop',
#  'hiphop',
#  'pop',
#  'electronic',
#  'Hip-Hop',
#  'alternative',
#  'Hip-Hop',
#  'pop',
#  'Hip-Hop',
#  'Nu Metal',
#  'Nu Metal',
#  'Nu Metal',
#  'alternative',
#  'alternative rock',
#  '90s',
#  '90s',
#  'Grunge',
#  'indie',
#  'like2009-2014',
#  'indie',
#  'punk rock',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'rock',
#  'rock',
#  'rock',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'Hip-Hop',
#  'rock',
#  'Hip-Hop',
#  'taylor swift',
#  'Hip-Hop',
#  'pop',
#  'Hip-Hop',
#  'Hip-Hop',
#  'pop',
#  'alternative metal',
#  'alternative metal',
#  'metal',
#  'rock',
#  'indie',
#  'punk',
#  'punk',
#  'punk',
#  'punk',
#  'alternative metal',
#  'alternative metal',
#  'indie',
#  'indie',
#  'alternative',
#  'indie',
#  'rock',
#  'indie',
#  'indie',
#  'indie',
#  'rock',
#  'indie',
#  'pop',
#  'Hip-Hop',
#  'Hip-Hop',
#  'indie',
#  'indie',
#  'indie',
#  'post-rock',
#  'emo',
#  'emo',
#  'Nu Metal',
#  'synthpop',
#  'dance',
#  'hiphop',
#  'Hip-Hop',
#  'synthpop',
#  'synthpop',
#  'pop',
#  'electronic',
#  'trap',
#  'pop',
#  'taylor swift',
#  'rock',
#  'Hip-Hop',
#  'hiphop',
#  'electronic',
#  'indie',
#  'pop',
#  'dance',
#  'hiphop',
#  'electronic',
#  'trap',
#  'american',
#  'alternative rock',
#  'strings and amps',
#  'Canadian',
#  'alternative rock',
#  'strings and amps',
#  'Canadian',
#  'Canadian',
#  'alternative rock',
#  'strings and amps',
#  'Canadian',
#  'emo',
#  'post-rock',
#  'emo',
#  'emo',
#  'emo',
#  'emo',
#  'indie',
#  'metalcore',
#  'metalcore',
#  'metalcore',
#  'emo',
#  'emo',
#  'rock',
#  'punk rock',
#  'punk rock',
#  'rock',
#  '80s',
#  'rap',
#  'folk',
#  '3 stars',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'post-rock',
#  'folk rock',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'alternative',
#  'indie',
#  'rock',
#  'indie',
#  'rock',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'metal',
#  'post-hardcore',
#  'screamo',
#  'post-hardcore',
#  'pop',
#  'indie',
#  'rock',
#  'rock',
#  'emo',
#  'indie',
#  'indie',
#  'emo',
#  'emo',
#  'emo',
#  'emo',
#  'post-rock',
#  'emo',
#  'emo',
#  'emo',
#  'indie',
#  '2015',
#  'indie',
#  'rock',
#  'british',
#  'pop',
#  'british',
#  'rock',
#  'indie',
#  'indie',
#  'post-rock',
#  'emo',
#  'indie',
#  'love at first listen',
#  'indie',
#  'british',
#  'indie',
#  'british',
#  'pop',
#  'love at first listen',
#  'love at first listen',
#  'rock',
#  'rock',
#  'rock',
#  'pop',
#  'love at first listen',
#  'Alternative Folk',
#  'folk',
#  'love at first listen',
#  'love at first listen',
#  'pop',
#  'dance',
#  'pop',
#  'lu',
#  'indie pop',
#  'indie',
#  'indie',
#  'pop',
#  'pop',
#  'classic rock',
#  'classic rock',
#  'love at first listen',
#  'indie pop',
#  'electronic',
#  'pop',
#  'pop',
#  'trap',
#  'pop',
#  'indie',
#  'indie pop',
#  'rock',
#  'indie',
#  '2015',
#  'indie',
#  'title track',
#  'indie pop',
#  'indie pop',
#  'rock',
#  'rock',
#  'rock',
#  'classic rock',
#  'classic rock',
#  'rock',
#  'classic rock',
#  'classic rock',
#  'classic rock',
#  'classic rock',
#  'rock',
#  'rock',
#  'rock',
#  'synthpop',
#  'Hip-Hop',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'rock',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'mixtape for next person i fall in love with',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'Hip-Hop',
#  'instrumental',
#  'post-rock',
#  'post-rock',
#  'emo',
#  'post-rock',
#  'emo',
#  'Hip-Hop',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'Hip-Hop',
#  'Hip-Hop',
#  'indie',
#  'indie pop',
#  'electronica',
#  'indie',
#  '2015',
#  'synthpop',
#  'mixtape for next person i fall in love with',
#  'alternative',
#  'rock',
#  'rock',
#  'post-hardcore',
#  'mixtape for next person i fall in love with',
#  'midnight',
#  'Grunge',
#  'Grunge',
#  'Grunge',
#  'Grunge',
#  'indie',
#  'like2009-2014',
#  'indie',
#  'electronic',
#  'indie',
#  'emo',
#  'emo',
#  'emo',
#  'emo',
#  'emo',
#  '2015',
#  '90s',
#  'Nu Metal',
#  'Grunge',
#  'alternative rock',
#  '1994',
#  'Grunge',
#  'rock',
#  'post-rock',
#  '90s',
#  'metal',
#  'alternative rock',
#  '90s',
#  'rock',
#  'classic rock',
#  'classic rock',
#  'rock',
#  'Grunge',
#  'pop',
#  'alternative',
#  'alternative',
#  'rock',
#  'indie',
#  'mixtape for next person i fall in love with',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'electronica',
#  'indie',
#  '2015',
#  'synthpop',
#  'indie',
#  '2015',
#  'synthpop',
#  'indie',
#  'midnight',
#  'cover',
#  'life is strange',
#  'somafm',
#  'electronic',
#  'indie',
#  'synthpop',
#  'love at first listen',
#  'mixtape for next person i fall in love with',
#  'mixtape for next person i fall in love with',
#  'pop',
#  'pop',
#  'electronic',
#  'pop',
#  'soul',
#  'love at first listen',
#  'pop',
#  'midnight',
#  'midnight',
#  'alternative',
#  'mixtape for next person i fall in love with',
#  'midnight',
#  'midnight',
#  'mixtape for next person i fall in love with',
#  'midnight',
#  'mixtape for next person i fall in love with',
#  '2015',
#  'electronic',
#  'alternative',
#  'sxsw 2016',
#  'midnight',
#  'electronic',
#  'pop',
#  'indie',
#  'rock',
#  'sxsw 2016',
#  'midnight',
#  'shoegaze',
#  'indie',
#  'acoustic',
#  'female vocalists',
#  'electronic',
#  'indie',
#  'bottom of a bottle',
#  '2013',
#  'indie',
#  'pop',
#  'electronic',
#  'dance',
#  'indie',
#  '2015',
#  'alternative',
#  'electronic',
#  'mixtape for next person i fall in love with',
#  'midnight',
#  'midnight',
#  'midnight',
#  'midnight',
#  'rock',
#  'indie pop',
#  '2015',
#  'electronica',
#  'indie',
#  'indie',
#  'indie pop',
#  'electronica',
#  'indie',
#  'handclaps',
#  'post-rock',
#  'fip',
#  'says the n word',
#  'indie',
#  'rock',
#  'pop punk',
#  'indie',
#  'folk',
#  'indie pop',
#  'alternative',
#  'freja',
#  'indie',
#  'rock',
#  'songs',
#  'female vocalists',
#  'electropop',
#  'electronic',
#  'folk',
#  'indie',
#  'emo',
#  'indie',
#  'electronic',
#  'folk',
#  'acoustic',
#  'beautiful',
#  'indie',
#  '2015',
#  'soul',
#  'cover',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'indie',
#  'post-rock',
#  'instrumental',
#  '3 stars',
#  '3 stars',
#  'blues rock',
#  'love at first listen',
#  'indie',
#  '3 stars',
#  '4 Stars',
#  'electronic',
#  'electronic',
#  'synthpop',
#  'synthpop',
#  'electronic',
#  'electronic',
#  'synthpop',
#  'synthpop',
#  'electronic',
#  'synthpop',
#  'synthpop',
#  '2015',
#  'electronica',
#  'indie',
#  'indie',
#  'electronica',
#  'indie',
#  '2015',
#  'synthpop',
#  'post-rock',
#  'instrumental',
#  'post-rock',
#  'indie',
#  'indie pop',
#  'electronica',
#  'indie',
#  '2015',
#  'synthpop',
#  'indie pop',
#  '2015',
#  'electronica',
#  'indie',
#  'indie',
#  'indie pop',
#  'electronica',
#  'indie',
#  '2015',
#  'synthpop',
#  'post-rock',
#  'blues rock',
#  '3 stars',
#  'indie',
#  'love at first listen',
#  '3 stars',
#  '3 stars',
#  '4 Stars',
#  'alternative rock',
#  'indie',
#  'indie pop',
#  'numbers',
#  'electronic',
#  'electronic',
#  'synthpop',
#  'indie',
#  '2015',
#  'synthpop',
#  'indie',
#  'indie',
#  'indie pop',
#  '2015',
#  'electronica',
#  'indie',
#  'indie',
#  'indie pop',
#  'electronica',
#  'indie',
#  '2015',
#  'synthpop',
#  'instrumental',
#  ...]

# %%
display(unique_genres)
# Out:
# ['90s',
#  'pop',
#  '80s',
#  'alternative rock',
#  'rock',
#  'Grunge',
#  'alternative metal',
#  'Nu Metal',
#  'alessia cara',
#  'funk',
#  'alternative',
#  'metal',
#  'indie',
#  'Hip-Hop',
#  'hiphop',
#  'rap',
#  'trap',
#  'meme rap',
#  'country',
#  'post-hardcore',
#  '2003',
#  'like2009-2014',
#  'screamo',
#  'hardcore',
#  'metalcore',
#  'folk',
#  'chillstep',
#  'electronic',
#  'electropop',
#  'sxsw 2017',
#  'lil yachty',
#  'Fave Indie Pop',
#  'conan',
#  'Philkas',
#  'sadboi',
#  'punk',
#  'synthpop',
#  '2015',
#  'american',
#  'emo',
#  'post-rock',
#  'electronica',
#  'soul',
#  'christmas',
#  'classic rock',
#  'catchy af',
#  'jazz',
#  'easy listening',
#  'punk rock',
#  'hip hop',
#  'future',
#  'hard rock',
#  'ost',
#  'taylor swift',
#  'dance',
#  'strings and amps',
#  'Canadian',
#  '3 stars',
#  'folk rock',
#  'british',
#  'love at first listen',
#  'Alternative Folk',
#  'lu',
#  'indie pop',
#  'title track',
#  'mixtape for next person i fall in love with',
#  'instrumental',
#  'midnight',
#  '1994',
#  'cover',
#  'life is strange',
#  'somafm',
#  'sxsw 2016',
#  'shoegaze',
#  'acoustic',
#  'female vocalists',
#  'bottom of a bottle',
#  '2013',
#  'handclaps',
#  'fip',
#  'says the n word',
#  'pop punk',
#  'freja',
#  'songs',
#  'beautiful',
#  'blues rock',
#  '4 Stars',
#  'numbers',
#  'what a voice',
#  'indie rock',
#  'winter morning',
#  'male vocalists',
#  'future bass',
#  'techno',
#  'scarlett johansson',
#  '2014',
#  'Meyers',
#  '2010s',
#  'sxsw 2015',
#  'chill',
#  'laid back',
#  'relevant magazine',
#  'Mellow',
#  'The Vampire Diaries',
#  'I may start dancing',
#  'so beautiful it will break your heart',
#  'comedy',
#  'played',
#  'Rave',
#  'design',
#  'audiosurfed',
#  'rnb',
#  'Progressive rock',
#  'f',
#  'trey songz',
#  'hip hop tag',
#  'christian',
#  'bernie stuteville',
#  'Dubstep Guns',
#  'dubstep',
#  'Lil Wayne',
#  'power pop',
#  'popular rock',
#  'Awesome song',
#  'Awesome',
#  'derivative',
#  'great',
#  'Alessandro Safina',
#  '360shift',
#  'brilliant',
#  'My Playlist',
#  'Favorite Derek Webb Songs',
#  'favorite tracks',
#  'laff',
#  'wonderful',
#  'Busta Rhymes',
#  'Megadeth',
#  'insane',
#  'stand-up comedy tag',
#  'xzibit',
#  'dr dre',
#  'chillout',
#  'classic',
#  'strings',
#  'Versus The Mirror',
#  'waltz',
#  'favorites']

# %%
print(len(genre_sequence))
# Out:
# 9200

# %%
print(len(unique_genres))
# Out:
# 147

# %%
# Save the genres collected using the scan above

for i in range(len(genre_sequence) - len(unique_genres)):
    unique_genres.append("None")
    
print(len(unique_genres))
# Out:
# 9200

# %%
import pandas as pd

genre_df = pd.DataFrame(data={'genre_sequence':genre_sequence, 'unique_genres':unique_genres})
genre_df.to_csv('genre_df.csv')

# %%
display(genre_df)
# Out:
#          genre_sequence      unique_genres
# 0                   90s                90s
# 1                   90s                pop
# 2                   pop                80s
# 3                   80s   alternative rock
# 4                   80s               rock
# 5      alternative rock             Grunge
# 6                  rock  alternative metal
# 7                Grunge           Nu Metal
# 8     alternative metal       alessia cara
# 9              Nu Metal               funk
# 10               Grunge        alternative
# 11                 rock              metal
# 12                 rock              indie
# 13         alessia cara            Hip-Hop
# 14                 funk             hiphop
# 15                 rock                rap
# 16                 rock               trap
# 17                 rock           meme rap
# 18                 rock            country
# 19          alternative      post-hardcore
# 20             Nu Metal               2003
# 21                metal      like2009-2014
# 22                  80s            screamo
# 23                  80s           hardcore
# 24                  80s          metalcore
# 25                indie               folk
# 26                indie          chillstep
# 27                indie         electronic
# 28              Hip-Hop         electropop
# 29               hiphop          sxsw 2017
# ...                 ...                ...
# 9170            screamo               None
# 9171            screamo               None
# 9172            screamo               None
# 9173            screamo               None
# 9174            screamo               None
# 9175      post-hardcore               None
# 9176           hardcore               None
# 9177               rock               None
# 9178         indie rock               None
# 9179               rock               None
# 9180              indie               None
# 9181            Awesome               None
# 9182              indie               None
# 9183                emo               None
# 9184                emo               None
# 9185                emo               None
# 9186           Canadian               None
# 9187           Canadian               None
# 9188               rock               None
# 9189              indie               None
# 9190              indie               None
# 9191        alternative               None
# 9192            Awesome               None
# 9193              indie               None
# 9194                emo               None
# 9195        alternative               None
# 9196               rock               None
# 9197               rock               None
# 9198        alternative               None
# 9199        alternative               None
#
# [9200 rows x 2 columns]

# %% [markdown]
# ## Collect the genre sequence for all of the friends

# %%
print(len(user_1_friends_track_array))
# Out:
# 15

# %%
import pandas as pd
for i in range(15, len(user_1_friends_track_array)):
    if(user_1_friends_track_array[i] != None):
        save_string = 'genre_df_' + str(i) + '.csv'
        sequence, unique = map_to_genre(user_1_friends_track_array[i])
        
        # Save the genres collected using the scan above

        for i in range(len(sequence) - len(unique)):
            unique.append("None")

        friend_genre_df = pd.DataFrame(data={'genre_sequence':sequence, 'unique_genres':unique})
        friend_genre_df.to_csv(save_string)
# Out:
# Key not found for track = Need+U+(100%)+feat.+A*M*E+(Original+Mix) and artist = Duke+Dumont
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Broken+( and artist = Seether
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Swing+Star+Pt+1+++Pt+2 and artist = Todd+Terje
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = dub+and+dwars and artist = Brainpower
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = +Dome and artist = Seekae
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Money+On+My+Mind+-+Radio+Edit and artist = Dirtcaps+and+The+Million+Plan
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = When+Your+Heart+Stops+Beating+-+Explicit+Version and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Diminished+-+LP+Version+++Hidden+Track+"I'm+Not+Over+You" and artist = R.E.M.
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Dying+feat.+Ultra+Violet+Sound+and+Emily+Hudson and artist = Kill+the+Noise
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Make+Up+Sex+(feat.+Olivier+Daysoul+and+Deacon+the+Villain+of+CunninLynguists) and artist = Substantial
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Island+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = No,+It+Isn't and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Wash.+(Dan+Huiting+and+Adam+Rucinski+Remix) and artist = Bon+Iver
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = After+All+These+Years+-+Album+Version+++Hidden+Track+"Outro" and artist = Silverchair
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 155 and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = No,+It+Isn't and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = When+Your+Heart+Stops+Beating+-+Explicit+Version and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Warrior+-+Mr.Polska,+Leo+and+Jebroer and artist = Nouveau+Riche
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Oeffer+-+Jebroer,+Leo,+Digitzz,+Steph+and+Mr.Polska and artist = Nouveau+Riche
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Miserable+at+Best and artist = Bram+and+Hinne
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Rawest+Form+Of+Rock+and+Roll and artist = Green+Day
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Third+Swan+-+single+version and artist = King+Creosote+and+Jon+Hopkins
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Just+Chill+[Feat.+Torae+and+MeLa+Machinko] and artist = Dela
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Interlude+[feat.+Marie+M+and+Brian+Jackson] and artist = Dela
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Fuck+Money+(Remix)+[feat.+Enz+and+Tasco] and artist = Dela
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = I+Remember+(Remix)+[Feat.+Supastition+and+Shamsya] and artist = Dela
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Time+Goes+By+(feat.+Hydroponiks+and+Anika) and artist = re:plus
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Substantial+and+L+Universe-Lyrical+Terrorists and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Wiggle+Baby+2 and artist = Mystery+Gang
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Waterfall+-+Bof+La+Vie+Est+Un+Miracle and artist = Emir+Kusturica+and+The+No+Smoking+Orchestra
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = You+Got+to+Go+-+Seven+Lions+Remix and artist = Above+and+Beyond
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Dying+feat.+Ultra+Violet+Sound+and+Emily+Hudson+(Brown+and+Gammon+Remix) and artist = Kill+the+Noise
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Twist+Of+Fate+-+Koishii+and+Hush+Remix and artist = Bad+Lieutenant
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Belle+and+Sebastian+Late+Night+Tales+(Continuous+Mix) and artist = Late+Night+Tales
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Stress+[feat.+Queens+Connex+and+Termanology] and artist = Dela
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = My+Ni@a+[feat.+Elzhi] and artist = Dela
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Chill+[feat.+Large+Professor+and+Meemee+Nelzy] and artist = Dela
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Echte+Jannen+van+zondag+13+mei and artist = Jan++Roos+and+Jan+Heemskerk
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Echte+Jannen+van+zondag+3+juni and artist = Jan++Roos+and+Jan+Heemskerk
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Echte+Jannen+van+zondag+3+juni and artist = Jan++Roos+and+Jan+Heemskerk
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+Bells+-+ and artist = Soulsavers
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Black+and+Blue+-+Acoustic+Session and artist = Paloma+Faith
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Island+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sonata+No.14+In+C+Min+Op.27/2+'Moonlight':+1St+Mvt. and artist = Ludwig+van+Beethoven
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Bubble+-+single+edit and artist = King+Creosote+and+Jon+Hopkins
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = John+Taylor's+Month+Away+-+Single+Version and artist = King+Creosote+and+Jon+Hopkins
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Third+Swan+-+single+version and artist = King+Creosote+and+Jon+Hopkins
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Gone+Are+The+Days+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Island+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Waiting+For+The+Clouds+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Yes+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Gone+Are+The+Days+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Island+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Waiting+For+The+Clouds+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Yes+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Gone+Are+The+Days+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Gone+Are+The+Days+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Gone+Are+The+Days+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = MARIAandJOKER and artist = 水樹奈々
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Gone+Are+The+Days+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+11+-+Land+Meets+Ocean and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+10+-+Heart+Goes+Down+Like+The+Sun and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+02+-+Angel+Sulk and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+07+-+Destiny+Stopped+Screaming and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+07+-+Destiny+Stopped+Screaming and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+13+-+Last+Train+Out+Of+Shatterville and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+12+-+Song+Damn+Song and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+11+-+Land+Meets+Ocean and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+10+-+Heart+Goes+Down+Like+The+Sun and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+09+-+In+The+Field and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+08+-+Get+Me+A+Witness and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+06+-+Summer+Wheels and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+05+-+Startime and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+04+-+Scrapyard and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+03+-+Forever+From+Here and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Adrian+Borland+-+Harmony+and+Destruction+-+02+-+Angel+Sulk and artist = Adrian+Borland
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Yes+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Yes+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Yes+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Pacification+(Part+1+and+2) and artist = Disia
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Forever+Yours+(ft.+Stacy+Epps+and+Toby+from+Inverse) and artist = HIDETAKE+TAKAYAMA
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Waiting+For+The+Clouds+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Yes+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Island+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Waiting+For+The+Clouds+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Yes+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = City+Lights+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Gone+Are+The+Days+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sky+Is+Tumbling+( and artist = Nujabes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Electric+Shaka+ and artist = Thunderball
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Say+My+Name+(1's+Edit) and artist = Destiny's+Child
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Throw+Some+D's+(remix) and artist = Rich+Boy+ft.+André+3000,+Jim+Jones,+Murphy+Lee+and+The+Game
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Say+My+Name+(1's+Edit) and artist = Destiny's+Child
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = I+Really+Want+To+Show+You+(Feat.+K-Ci+and+Jo-Jo+and+Nas) and artist = The+Notorious+B.I.G.
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Tuning+Rap+and+The+Old+Laughing+Lady+Intro+[Live] and artist = Neil+Young
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Winterlong+[Excerpt]+and+Out+Of+My+Mind+Intro+[Live] and artist = Neil+Young
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Tuning+Rap+and+The+Old+Laughing+Lady+Intro+[Live] and artist = Neil+Young
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Atlantic+City+(live) and artist = Matt+Nathanson,+David+Immergluck+and+Charlie+Gillingham
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Pursuit+of+Happiness++(Thrills+and+Tony+Rocky+Horror+Remix) and artist = Kid+Cudi
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Rock+Yo+Hips+( and artist = Crime+Mob
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Drumming+Song+-+MTV+Unplugged,+2012 and artist = Florence+++the+Machine
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Only+If+For+A+Night+-+MTV+Unplugged,+2012 and artist = Florence+++the+Machine
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Walking+alone+(Radio+Edit) and artist = Dirty+South+and+Those+Usual+Suspects+feat.+Erik+Hecht
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Walking+alone+(Radio+Edit) and artist = Dirty+South+and+Those+Usual+Suspects+feat.+Erik+Hecht
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Walking+alone+(Radio+Edit) and artist = Dirty+South+and+Those+Usual+Suspects+feat.+Erik+Hecht
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Walking+alone+(Radio+Edit) and artist = Dirty+South+and+Those+Usual+Suspects+feat.+Erik+Hecht
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Walking+alone+(Radio+Edit) and artist = Dirty+South+and+Those+Usual+Suspects+feat.+Erik+Hecht
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 在你身边 and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 晚安,地球人+疯狂世界+(Goodnight,+Earthman+++Mad+World) and artist = 五月天
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 晚安,地球人+疯狂世界+(Goodnight,+Earthman+++Mad+World) and artist = 五月天
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 晚安,地球人+疯狂世界+(Goodnight,+Earthman+++Mad+World) and artist = 五月天
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 陈胜吴广 and artist = 高旗and超载
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 晚安,地球人+疯狂世界+(Goodnight,+Earthman+++Mad+World) and artist = 五月天
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 陈胜吴广 and artist = 高旗and超载
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 在你身边 and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 在你身边 and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 在你身边 and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 在你身边 and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 序曲+天空之城（吟唱版） and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 在你身边 and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 在你身边 and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 序曲+天空之城（吟唱版） and artist = 小娟and山谷里的居民
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+__+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+__+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+__+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+__+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+__+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+//+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+__+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Knocking+at+the+Door and artist = Laws+and+Paul+McCartney
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+//+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+//+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Death+and+Dreaming+//+Overture and artist = Future+Flutes
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Around+The+World+(Benoit+and+Sergio+Remix) and artist = Daft+Punk
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Disarm+the+Sun+and+Moon+(DJ+Goober+Mashup) and artist = Above+and+Beyond+vs+Dash+Berlin
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Someone+Like+You+(Adele+++Christina+Grimmie) and artist = Skylė
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Quacky+-+DJ+eWreck+Edit and artist = Afrojack+and+Sidney+Samson
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Lemonface and artist = Spenca+and+AFK
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = The+Choosen and artist = Loop+Stepwalker+and+Sinister+Souls
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Funkin+Pon+The+Streets+(Beatz[NJ]+Re-MashUp) and artist = Frankie+Steel+and+DJ+4B
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = R.N.Berretta's+Florence+and+The+Machine+vs.+Skrillex+Mashup and artist = Ryan+Nicholas+Berretta
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sierra+Leone+-+The+Phat+Riderz+Remix and artist = Agent+K+and+Bella
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Acid+Bitch+(Vocal+Club) and artist = Accenter+and+Three+O.
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Bullets+(Nause+and+Adrian+Lux+Remix+Radio) and artist = Rebecca+and+Fiona
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Promises+(Skrillex+and+Nero+Remix) and artist = Nero+F.+Sub+Focus
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ballad+of+Kurt+Vile+2 and artist = Sweet+Lights
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Down+Below and artist = Johannes+Stankowski/prod.+and+arranged+by+Michael+Kadelbach
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Rabbit+Heart+Slof+Man+Dubstep+Mix+1 and artist = Florence+++the+Machine
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Ghosts+'n+Stuff+( and artist = deadmau5
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Sleeping and artist = Glen+Hansard+and+Mark
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = 155 and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = When+Your+Heart+Stops+Beating and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Make+You+Smile and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = No,+It+Isn't and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Make+You+Smile and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
# Key not found for track = Baby+Come+On and artist = +44
# {'error': 6, 'message': 'Track not found', 'links': []}
